# %%
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt

# %%
# Path to download data to
file = '/Users/ljob/Downloads/CFS_APCP_Basin_Sums.csv'

# %%
apcp = pd.read_csv(file)

# %%
print(apcp)
# Out:
#           cfsrun  year  month     BasinErie     WaterErie      LandErie  \
# 0     2024031600  2024      3  9.384073e+12  1.737966e+12  8.761280e+12
# 1     2024031600  2024      4  6.316287e+12  9.813252e+11  6.296658e+12
# 2     2024031600  2024      5  7.853017e+12  1.189906e+12  7.815951e+12
# 3     2024031600  2024      6  4.755265e+12  7.012387e+11  4.881320e+12
# 4     2024031600  2024      7  5.964431e+12  8.842948e+11  5.964004e+12
# ...          ...   ...    ...           ...           ...           ...
# 4363  2024070718  2024     12  7.394103e+12  1.298765e+12  7.108964e+12
# 4364  2024070718  2025      1  5.937085e+12  1.008356e+12  5.639077e+12
# 4365  2024070718  2025      2  5.116827e+12  8.770965e+11  4.801036e+12
# 4366  2024070718  2025      3  8.066581e+12  1.289093e+12  7.753303e+12
# 4367  2024070718  2025      4  4.318775e+12  6.502641e+11  4.314311e+12
#
#       BasinOntario  WaterOntario   LandOntario    BasinHuron    WaterHuron  \
# ...

# %%
data_7  = apcp[(apcp['month'] == 7) & (apcp['year'] == 2024)]

# %%
print(data_7)
# Out:
#           cfsrun  year  month     BasinErie     WaterErie      LandErie  \
# 4     2024031600  2024      7  5.964431e+12  8.842948e+11  5.964004e+12
# 14    2024031606  2024      7  6.153483e+12  8.659903e+11  6.205112e+12
# 24    2024031612  2024      7  7.851224e+12  1.175969e+12  7.989368e+12
# 34    2024031618  2024      7  7.941851e+12  1.274627e+12  7.735258e+12
# 44    2024031700  2024      7  1.162266e+13  1.784284e+12  1.210323e+13
# ...          ...   ...    ...           ...           ...           ...
# 4318  2024070618  2024      7  1.249290e+13  2.064100e+12  1.200950e+13
# 4328  2024070700  2024      7  1.041418e+13  1.547013e+12  1.038143e+13
# 4338  2024070706  2024      7  6.784782e+12  1.012710e+12  7.150268e+12
# 4348  2024070712  2024      7  1.045026e+13  1.576090e+12  1.053139e+13
# 4358  2024070718  2024      7  9.704162e+12  1.429963e+12  9.678833e+12
#
#       BasinOntario  WaterOntario   LandOntario    BasinHuron    WaterHuron  \
# ...

# %%
sa_sup = 82097*1000000
sa_mih = (57753 + 5956)*1000000
sa_eri = 25655*1000000
sa_ont = 19009*1000000

# %%
fig, axs = plt.subplots(1, 1, figsize=(15, 5))

axs.plot(data_7.index, data_7['WaterErie']/sa_eri)

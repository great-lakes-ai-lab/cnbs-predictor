# %% [markdown]
# # Model Training Script
# Lindsay Fitzpatrick
# ljob@umich.edu
# 12/18/2024
#
# This script reads in CFSR data from 1979 - 2010 and trains machine learning models to target CNBS from L2SWBM across the 5 Great Lakes simultaeously.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import WhiteKernel, ConstantKernel, RBF, Matern, RationalQuadratic, ExpSineSquared
from sklearn.metrics import mean_squared_error, r2_score
#import tensorflow as tf
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
import joblib
import calendar

# %% [markdown]
# ## Functions

# %% [markdown]
# User Input

# %%
# This is the directory where the CFSR and L2SWBM files are located
dir = 'C:/Users/fitzpatrick/Desktop/Data/'

# %%
def seconds_in_month(year, month):
    # Number of days in the month
    num_days = calendar.monthrange(year, month)[1]
    # Convert days to seconds
    return num_days * 24 * 60 * 60

# %%
def shift_variables(df, lag=0, forecast=0):
    """
    Create the variables columns to include lags (last month values) and forecast variables
    
    Parameters:
    - df (pd.DataFrame): The DataFrame containing the time series data.
    - lag (int): The number of months you want to include lagged variables. Default = 0
    - forecast (int): The number of months for the forecast variables. Default = 0
    
    Returns:
    - pd.DataFrame: The DataFrame with added variable columns for lags and forecasting.
    """
    df = df.copy()  # To avoid modifying the original DataFrame

    # Generate target columns for the next `forecast_months` months
    for column in df.columns:
        for lag in range(1, lag + 1):
            df[f'{column}_mo-{lag}'] = df[column].shift(lag)
        for month in range(1, forecast+1):
            df[f'{column}_mo{month}'] = df[column].shift(-month)

    # Drop rows with any NaN values generated by shifting for the target
    df = df.dropna()

    return df

# %% [markdown]
# ## Begin Script

# %%
## Read in PCP data from CFSR [mm]
data_1 = pd.read_csv(dir+'CFSR/CFSR_APCP_Basin_Avgs_05.csv',sep=',')

## Read in EVAP data from CFSR [mm]
data_2 = pd.read_csv(dir+'CFSR/CFSR_EVAP_Basin_Avgs_031.csv',sep=',')

## Read in TMP data from CFSR [K]
data_3 = pd.read_csv(dir+'CFSR/CFSR_TMP_Basin_Avgs_031.csv',sep=',')

## Read in SWE data from CFSR [mm]
data_4 = pd.read_csv(dir+'CFSR/CFSR_SWE_Basin_Avgs_031.csv',sep=',')

## Read in SST data from CFSR [K]
data_5 = pd.read_csv(dir+'CFSR/CFSR_STMP_Basin_Avgs_031.csv',sep=',')

# %% [markdown]
# Read in L2SWBM in [mm]
#
# https://zenodo.org/records/13883098

# %%
sup_evap = pd.read_csv(dir + 'L2SWBM/superiorEvap_MonthlyRun.csv')
sup_runoff = pd.read_csv(dir + 'L2SWBM/superiorRunoff_MonthlyRun.csv')
sup_precip = pd.read_csv(dir + 'L2SWBM/superiorPrecip_MonthlyRun.csv')

eri_evap = pd.read_csv(dir + 'L2SWBM/erieEvap_MonthlyRun.csv')
eri_runoff = pd.read_csv(dir + 'L2SWBM/erieRunoff_MonthlyRun.csv')
eri_precip = pd.read_csv(dir + 'L2SWBM/eriePrecip_MonthlyRun.csv')

ont_evap = pd.read_csv(dir + 'L2SWBM/ontarioEvap_MonthlyRun.csv')
ont_runoff = pd.read_csv(dir + 'L2SWBM/ontarioRunoff_MonthlyRun.csv')
ont_precip = pd.read_csv(dir + 'L2SWBM/ontarioPrecip_MonthlyRun.csv')

mih_evap = pd.read_csv(dir + 'L2SWBM/miHuronEvap_MonthlyRun.csv')
mih_runoff = pd.read_csv(dir + 'L2SWBM/miHuronRunoff_MonthlyRun.csv')
mih_precip = pd.read_csv(dir + 'L2SWBM/miHuronPrecip_MonthlyRun.csv')

# %% [markdown]
# Here we prepare the data for training and testing. We set the features 'X' as total over lake
# precipitation, total over lake evaporation, and the average air temperature over each lake. The
# targets 'y' are RNBS for each lake simultaeously.

# %%
# Features
X = pd.DataFrame({
    'sup_pcp_w': data_1['sup_lake'],
    'eri_pcp_w': data_1['eri_lake'],
    'ont_pcp_w': data_1['ont_lake'],
    'mih_pcp_w': data_1['mih_lake'],
    'sup_pcp_l': data_1['sup_land'],
    'eri_pcp_l': data_1['eri_land'],
    'ont_pcp_l': data_1['ont_land'],
    'mih_pcp_l': data_1['mih_land'],
    'sup_evap_w': data_2['sup_lake'],
    'eri_evap_w': data_2['eri_lake'],
    'ont_evap_w': data_2['ont_lake'],
    'mih_evap_w': data_2['mih_lake'],
    'sup_evap_l': data_2['sup_land'],
    'eri_evap_l': data_2['eri_land'],
    'ont_evap_l': data_2['ont_land'],
    'mih_evap_l': data_2['mih_land'],
    'sup_tmp_w': data_3['sup_lake'],
    'eri_tmp_w': data_3['eri_lake'],
    'ont_tmp_w': data_3['ont_lake'],
    'mih_tmp_w': data_3['mih_lake'],
    'sup_tmp_l': data_3['sup_land'],
    'eri_tmp_l': data_3['eri_land'],
    'ont_tmp_l': data_3['ont_land'],
    'mih_tmp_l': data_3['mih_land']
})

# Set the index by date
X.set_index(pd.to_datetime(data_1[['year', 'month']].assign(day=1)), inplace=True)

# Targets are the components of NBS (P, E, R)
targets = pd.DataFrame({
    'sup_evap_t': sup_evap['Median'],
    'sup_pcp_t': sup_precip['Median'],
    'sup_rnoff_t': sup_runoff['Median'],
    'eri_evap_t': eri_evap['Median'],
    'eri_pcp_t': eri_precip['Median'],
    'eri_rnoff_t': eri_runoff['Median'],
    'ont_evap_t': ont_evap['Median'],
    'ont_pcp_t': ont_precip['Median'],
    'ont_rnoff_t': ont_runoff['Median'],
    'mih_evap_t': mih_evap['Median'],
    'mih_pcp_t': mih_precip['Median'],
    'mih_rnoff_t': mih_runoff['Median'],
})

# Set the index of the targets
targets.set_index(pd.to_datetime(eri_evap[['Year', 'Month']].assign(day=1)), inplace=True)

# %%
shifted_X = shift_variables(X ,lag=0, forecast=8)
# Out:
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)

# %%
shifted_targets = shift_variables(targets, lag=0, forecast=11)
# Out:
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)
# C:\Users\fitzpatrick\AppData\Local\Temp\2\ipykernel_6548\1642517307.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{column}_mo{month}'] = df[column].shift(-month)

# %%
# Current Basin conditions
X2 = pd.DataFrame({
    'sup_swe_l': data_4['sup_land'],
    'eri_swe_l': data_4['eri_land'],
    'ont_swe_l': data_4['ont_land'],
    'mih_swe_l': data_4['mih_land'],
    'mih_sst_w': data_5['mih_lake'],
    'eri_sst_w': data_5['eri_lake'],
    'ont_sst_w': data_5['ont_lake'],
    'mih_sst_w': data_5['mih_lake'],
})

# Set the index by date
X2.set_index(pd.to_datetime(data_4[['year', 'month']].assign(day=1)), inplace=True)

# %%
shifted_X2 = shift_variables(X2, lag=0, forecast=0)

# %%
merged_X = pd.merge(shifted_X, shifted_X2, left_index=True, right_index=True, how='inner')

# %%
# Make sure the indices/dates align after the shifts
aligned_y = shifted_targets.loc[shifted_X.index]

print(f'Number of Targets: {aligned_y.shape[1]}')
print(f'Number of Features: {merged_X.shape[1]}')
# Out:
# Number of Targets: 144
# Number of Features: 223

# %% [markdown]
# Split the data into training and testing data sets. We could do it as a random 80/20 split
# but instead we set split the data set by date ranges. This can easily be adjusted.

# %%
# Split data into training and testing sets
#X_train, X_test, y_train, y_test = train_test_split(lagged_X, y, test_size=0.2, random_state=42)
train_start_date = '1979-01-01'
train_end_date = '2004-12-01'
# Testing dataset
val_start_date = '2005-01-01'
val_end_date = '2011-01-01'

#X_train = shifted_X[train_start_date:train_end_date]
X_train = merged_X[train_start_date:train_end_date]
y_train = aligned_y[train_start_date:train_end_date]
#X_test = shifted_X[val_start_date:val_end_date]
X_test = merged_X[val_start_date:val_end_date]
y_test = aligned_y[val_start_date:val_end_date]

# %%
# Verify shapes
print("Shape of X_train:", X_train.shape)
print("Shape of y_train:", y_train.shape)
print("Shape of X_test:", X_test.shape)
print("Shape of y_test:", y_test.shape)
# Out:
# Shape of X_train: (312, 223)
# Shape of y_train: (312, 144)
# Shape of X_test: (64, 223)
# Shape of y_test: (64, 144)

# %% [markdown]
# It is best practice to standardize the data from 0-1 before training

# %%
# Standardize the data
x_scaler = StandardScaler()
y_scaler = StandardScaler()
X_train_scaled = x_scaler.fit_transform(X_train)
X_test_scaled = x_scaler.fit_transform(X_test)
y_train_scaled = y_scaler.fit_transform(y_train)
y_test_scaled = y_scaler.fit_transform(y_test)
# Out:
# (312, 223)
# (64, 223)

# %% [markdown]
# ## Training
# Below we train different models using the same data and calculate the r squared values on the
# test data to compare performance.

# %%
# Testing Different Kernels
# Basic kernel using ConstantKernel: r2 = 0.8259
#kernel = ConstantKernel(1.0, (1e-3, 1e3)) * RBF(1.0, (1e-2, 1e2))

# Matt's optimal kernel: 
# # MVP r2 = 0.8159
# # Geo mask r2: 0.8176
# # 
kernel = 1.0 * Matern(nu=1.5) * RationalQuadratic()

# Test to add a seasonality component: r2 = 0.8279
#period = 3.0  # Period of the season
#kernel = ConstantKernel(1.0, (1e-3, 1e3)) * RBF(length_scale=1.0, length_scale_bounds=(1e-2, 1e2)) + ExpSineSquared(length_scale=1.0, periodicity=period, periodicity_bounds=(1e-2, 1e2))

#kernel = 1.0 * ExpSineSquared(periodicity=12)

#kernel = 1.0 * RBF() + 1.0 * Matern(nu=2.5) + 1.0 * RationalQuadratic()

# Set up the model
gpr = GaussianProcessRegressor(kernel=kernel, alpha=0.1, n_restarts_optimizer=10, random_state=42)

# Fit the model
gpr.fit(X_train_scaled, y_train_scaled)

# Save the trained model
#joblib.dump(gpr, 'GP_trained_model.joblib')
#joblib.dump(x_scaler, 'x_scaler.joblib')
#joblib.dump(y_scaler, 'y_scaler.joblib')

# Predictions
y_pred, sigma = gpr.predict(X_test_scaled, return_std=True)

# Calculate Mean Squared Error
mse = mean_squared_error(y_test_scaled, y_pred)
r_squared = r2_score(y_test_scaled, y_pred)
print(f"The r squared value for the model is {r_squared}")
print(f"Mean Squared Error: {mse}")
# Out:
# The r squared value for the model is 0.7427189240305423
# Mean Squared Error: 0.2572810759694576
# c:\Users\fitzpatrick\AppData\Local\miniconda3\envs\myenv\Lib\site-packages\sklearn\gaussian_process\kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(

# %%
## Random Forest Regressor Model: r2 = 0.7389

# Initialize RandomForestRegressor
model = RandomForestRegressor(random_state=42)

# Train the model
model.fit(X_train, y_train)

# Save the trained model
joblib.dump(model, 'RF_trained_model.joblib')

# Predict on the test set
y_pred = model.predict(X_test)

# Calculate Mean Squared Error
mse = mean_squared_error(y_test, y_pred)
r_squared = r2_score(y_test, y_pred)
print(f"The r squared value for the model is {r_squared}")
print(f"Mean Squared Error: {mse}")
# Out:
# The r squared value for the model is 0.6928700987238622
# Mean Squared Error: 388.8125664945563

# %%
## Linear Regression Model 

# Initialize Linear Regression model
model = LinearRegression()

# Fit the model
model.fit(X_train, y_train)

# Save the trained model
joblib.dump(model, 'LR_trained_model.joblib')

# Make predictions
y_pred = model.predict(X_test)

# Calculate Mean Squared Error
mse = mean_squared_error(y_test, y_pred)
r_squared = r2_score(y_test, y_pred)
print(f"The r squared value for the model is {r_squared}")
print(f"Mean Squared Error: {mse}")

# Get feature names from the DataFrame
feature_names = lagged_X.columns

# Get coefficients
coefficients = model.coef_

# Create a DataFrame for better visualization
importance_df = pd.DataFrame()

# Iterate through each target variable and store its coefficients
for i, target in enumerate(y.columns):
    target_importance_df = pd.DataFrame({
        'Feature': lagged_X.columns,
        'Coefficient': coefficients[i]  # Get coefficients for the i-th target
    })
    target_importance_df['Absolute Importance'] = target_importance_df['Coefficient'].abs()
    target_importance_df = target_importance_df.sort_values(by='Absolute Importance', ascending=False)
    target_importance_df['Target'] = target  # Add the target variable name
    importance_df = pd.concat([importance_df, target_importance_df], ignore_index=True)

# Set display option to show all rows
pd.set_option('display.max_rows', None)

# Print ranked features for each target
print(importance_df[['Target', 'Feature', 'Coefficient', 'Absolute Importance']])
# Out:
# The r squared value for the model is 0.7789350664714867
# Mean Squared Error: 307.8098635510663
#         Target         Feature  Coefficient  Absolute Importance
# 0    su_evap_y   er_tmp_w_lag1     6.193755             6.193755
# 1    su_evap_y   mh_tmp_w_lag1    -3.811819             3.811819
# 2    su_evap_y   er_tmp_l_lag1    -3.754319             3.754319
# 3    su_evap_y   su_tmp_w_lag1     3.658583             3.658583
# 4    su_evap_y   mh_tmp_l_lag1     3.413491             3.413491
# 5    su_evap_y        er_tmp_w    -2.474675             2.474675
# 6    su_evap_y        er_tmp_l    -2.022807             2.022807
# 7    su_evap_y   on_tmp_l_lag1    -1.640946             1.640946
# 8    su_evap_y        on_tmp_l     1.601433             1.601433
# 9    su_evap_y   on_tmp_w_lag1    -1.464392             1.464392
# 10   su_evap_y        su_tmp_l     1.430730             1.430730
# 11   su_evap_y        su_tmp_w    -1.394511             1.394511
# 12   su_evap_y   su_tmp_l_lag1     0.985434             0.985434
# 13   su_evap_y       su_evap_w     0.848416             0.848416
# 14   su_evap_y  su_evap_l_lag1    -0.582729             0.582729
# 15   su_evap_y       su_evap_l     0.475054             0.475054
# 16   su_evap_y       on_evap_l    -0.361113             0.361113
# 17   su_evap_y       er_evap_l     0.329348             0.329348
# 18   su_evap_y       on_evap_w     0.274392             0.274392
# 19   su_evap_y       mh_evap_w    -0.257968             0.257968
# 20   su_evap_y  er_evap_l_lag1    -0.207507             0.207507
# 21   su_evap_y   mh_pcp_l_lag1     0.189343             0.189343
# 22   su_evap_y        on_tmp_w    -0.187252             0.187252
# 23   su_evap_y        mh_tmp_w     0.182540             0.182540
# 24   su_evap_y       mh_evap_l    -0.161906             0.161906
# 25   su_evap_y  su_evap_w_lag1     0.135828             0.135828
# 26   su_evap_y        mh_tmp_l     0.131528             0.131528
# 27   su_evap_y   su_pcp_l_lag1     0.131283             0.131283
# 28   su_evap_y       er_evap_w    -0.118812             0.118812
# 29   su_evap_y        er_pcp_l    -0.112002             0.112002
# 30   su_evap_y   on_pcp_w_lag1    -0.110132             0.110132
# 31   su_evap_y   er_pcp_l_lag1    -0.103014             0.103014
# 32   su_evap_y   on_pcp_l_lag1     0.098841             0.098841
# 33   su_evap_y        su_pcp_l    -0.094518             0.094518
# 34   su_evap_y   mh_pcp_w_lag1    -0.078758             0.078758
# 35   su_evap_y        er_pcp_w     0.072936             0.072936
# 36   su_evap_y  mh_evap_l_lag1     0.072375             0.072375
# 37   su_evap_y        on_pcp_l     0.070928             0.070928
# 38   su_evap_y   er_pcp_w_lag1     0.064542             0.064542
# 39   su_evap_y  er_evap_w_lag1     0.039121             0.039121
# 40   su_evap_y  on_evap_l_lag1     0.037573             0.037573
# 41   su_evap_y        on_pcp_w    -0.031242             0.031242
# 42   su_evap_y   su_pcp_w_lag1    -0.025137             0.025137
# 43   su_evap_y  on_evap_w_lag1    -0.023534             0.023534
# 44   su_evap_y  mh_evap_w_lag1     0.020825             0.020825
# 45   su_evap_y        mh_pcp_w     0.014216             0.014216
# 46   su_evap_y        su_pcp_w     0.007457             0.007457
# 47   su_evap_y        mh_pcp_l     0.000125             0.000125
# 48   su_precip   su_tmp_w_lag1    -4.570941             4.570941
# 49   su_precip        on_tmp_l     3.017672             3.017672
# 50   su_precip   su_tmp_l_lag1     2.937466             2.937466
# 51   su_precip        su_tmp_l    -2.576701             2.576701
# 52   su_precip   mh_tmp_w_lag1     2.082794             2.082794
# 53   su_precip        mh_tmp_w    -1.437567             1.437567
# 54   su_precip   on_tmp_w_lag1    -1.392386             1.392386
# 55   su_precip        er_tmp_l     1.209065             1.209065
# 56   su_precip  su_evap_l_lag1     0.502317             0.502317
# 57   su_precip        su_pcp_w     0.486702             0.486702
# 58   su_precip       on_evap_w     0.472351             0.472351
# 59   su_precip  mh_evap_w_lag1    -0.438600             0.438600
# 60   su_precip       su_evap_w    -0.412515             0.412515
# 61   su_precip  on_evap_l_lag1    -0.407454             0.407454
# 62   su_precip  mh_evap_l_lag1    -0.401737             0.401737
# 63   su_precip        su_tmp_w    -0.380944             0.380944
# 64   su_precip  er_evap_l_lag1     0.368998             0.368998
# 65   su_precip   mh_tmp_l_lag1     0.356706             0.356706
# 66   su_precip        er_tmp_w     0.349493             0.349493
# 67   su_precip       on_evap_l     0.339302             0.339302
# 68   su_precip       er_evap_w    -0.322676             0.322676
# 69   su_precip        su_pcp_l     0.317495             0.317495
# 70   su_precip   mh_pcp_l_lag1    -0.293184             0.293184
# 71   su_precip   on_tmp_l_lag1     0.284017             0.284017
# 72   su_precip   mh_pcp_w_lag1     0.268257             0.268257
# 73   su_precip  er_evap_w_lag1     0.257984             0.257984
# 74   su_precip       su_evap_l    -0.249394             0.249394
# 75   su_precip   on_pcp_l_lag1     0.211798             0.211798
# 76   su_precip       mh_evap_w     0.210168             0.210168
# 77   su_precip  su_evap_w_lag1     0.208528             0.208528
# 78   su_precip   er_tmp_l_lag1     0.164972             0.164972
# 79   su_precip        er_pcp_w     0.121798             0.121798
# 80   su_precip   su_pcp_l_lag1     0.118558             0.118558
# 81   su_precip        er_pcp_l    -0.113007             0.113007
# 82   su_precip   su_pcp_w_lag1    -0.101887             0.101887
# 83   su_precip   er_pcp_w_lag1    -0.095708             0.095708
# 84   su_precip       er_evap_l    -0.089028             0.089028
# 85   su_precip        on_pcp_l    -0.085429             0.085429
# 86   su_precip        mh_pcp_l    -0.082783             0.082783
# 87   su_precip  on_evap_w_lag1     0.081268             0.081268
# 88   su_precip        on_tmp_w    -0.074654             0.074654
# 89   su_precip   er_tmp_w_lag1    -0.061556             0.061556
# 90   su_precip       mh_evap_l    -0.052834             0.052834
# 91   su_precip        mh_pcp_w     0.050702             0.050702
# 92   su_precip        on_pcp_w    -0.044072             0.044072
# 93   su_precip   on_pcp_w_lag1    -0.035877             0.035877
# 94   su_precip        mh_tmp_l    -0.030205             0.030205
# 95   su_precip   er_pcp_l_lag1    -0.002199             0.002199
# 96   su_runoff        on_tmp_l    13.455254            13.455254
# 97   su_runoff        on_tmp_w   -12.117167            12.117167
# 98   su_runoff   on_tmp_w_lag1     7.067530             7.067530
# 99   su_runoff   on_tmp_l_lag1    -5.984568             5.984568
# 100  su_runoff   mh_tmp_w_lag1    -4.877180             4.877180
# 101  su_runoff        mh_tmp_l     4.307664             4.307664
# 102  su_runoff        er_tmp_l    -4.196278             4.196278
# 103  su_runoff   mh_tmp_l_lag1     3.483381             3.483381
# 104  su_runoff   er_tmp_w_lag1     2.782544             2.782544
# 105  su_runoff        mh_tmp_w    -2.270225             2.270225
# 106  su_runoff   su_tmp_l_lag1    -1.944336             1.944336
# 107  su_runoff        er_tmp_w    -1.627398             1.627398
# 108  su_runoff        su_tmp_w     1.300408             1.300408
# 109  su_runoff   su_tmp_w_lag1     0.867670             0.867670
# 110  su_runoff        su_tmp_l    -0.456934             0.456934
# 111  su_runoff   er_tmp_l_lag1    -0.448286             0.448286
# 112  su_runoff   su_pcp_l_lag1     0.297302             0.297302
# 113  su_runoff  su_evap_l_lag1     0.239676             0.239676
# 114  su_runoff       er_evap_l     0.205383             0.205383
# 115  su_runoff       su_evap_w    -0.196593             0.196593
# 116  su_runoff       mh_evap_w     0.178851             0.178851
# 117  su_runoff       su_evap_l    -0.159857             0.159857
# 118  su_runoff        mh_pcp_l    -0.152610             0.152610
# 119  su_runoff   su_pcp_w_lag1    -0.128184             0.128184
# 120  su_runoff  er_evap_l_lag1    -0.121032             0.121032
# 121  su_runoff        su_pcp_l     0.115503             0.115503
# 122  su_runoff        on_pcp_l    -0.113742             0.113742
# 123  su_runoff        mh_pcp_w     0.107258             0.107258
# 124  su_runoff       on_evap_w     0.090060             0.090060
# 125  su_runoff        su_pcp_w     0.082974             0.082974
# 126  su_runoff        er_pcp_l     0.070965             0.070965
# 127  su_runoff  su_evap_w_lag1    -0.069962             0.069962
# 128  su_runoff   er_pcp_l_lag1    -0.066846             0.066846
# 129  su_runoff  mh_evap_w_lag1    -0.065461             0.065461
# 130  su_runoff   er_pcp_w_lag1     0.065353             0.065353
# 131  su_runoff       mh_evap_l    -0.055647             0.055647
# 132  su_runoff   on_pcp_w_lag1     0.052699             0.052699
# 133  su_runoff  mh_evap_l_lag1    -0.050970             0.050970
# 134  su_runoff  on_evap_l_lag1    -0.047819             0.047819
# 135  su_runoff   on_pcp_l_lag1    -0.040286             0.040286
# 136  su_runoff       er_evap_w    -0.038108             0.038108
# 137  su_runoff   mh_pcp_l_lag1    -0.022452             0.022452
# 138  su_runoff        on_pcp_w     0.020958             0.020958
# 139  su_runoff       on_evap_l    -0.019955             0.019955
# 140  su_runoff  er_evap_w_lag1    -0.013757             0.013757
# 141  su_runoff  on_evap_w_lag1    -0.013322             0.013322
# 142  su_runoff        er_pcp_w    -0.006173             0.006173
# 143  su_runoff   mh_pcp_w_lag1    -0.003306             0.003306
# 144  er_evap_y        er_tmp_w    -7.394068             7.394068
# 145  er_evap_y        su_tmp_l     7.078668             7.078668
# 146  er_evap_y   er_tmp_w_lag1     4.865788             4.865788
# 147  er_evap_y        su_tmp_w    -4.498541             4.498541
# 148  er_evap_y        on_tmp_w     4.469995             4.469995
# 149  er_evap_y   mh_tmp_l_lag1    -3.714763             3.714763
# 150  er_evap_y   su_tmp_w_lag1     3.711898             3.711898
# 151  er_evap_y   on_tmp_w_lag1     2.720213             2.720213
# 152  er_evap_y        mh_tmp_l    -2.453549             2.453549
# 153  er_evap_y   on_tmp_l_lag1    -2.245572             2.245572
# 154  er_evap_y        er_tmp_l     1.815406             1.815406
# 155  er_evap_y   mh_tmp_w_lag1     1.782176             1.782176
# 156  er_evap_y        mh_tmp_w    -1.273585             1.273585
# 157  er_evap_y  su_evap_l_lag1    -0.866448             0.866448
# 158  er_evap_y       er_evap_w     0.812440             0.812440
# 159  er_evap_y        on_tmp_l     0.588206             0.588206
# 160  er_evap_y  er_evap_w_lag1    -0.498604             0.498604
# 161  er_evap_y       mh_evap_l    -0.446262             0.446262
# 162  er_evap_y  on_evap_w_lag1     0.390551             0.390551
# 163  er_evap_y        su_pcp_l     0.341819             0.341819
# 164  er_evap_y  mh_evap_l_lag1     0.314785             0.314785
# 165  er_evap_y        er_pcp_l    -0.295151             0.295151
# 166  er_evap_y   er_tmp_l_lag1    -0.277480             0.277480
# 167  er_evap_y        mh_pcp_l     0.258218             0.258218
# 168  er_evap_y       er_evap_l     0.246526             0.246526
# 169  er_evap_y       su_evap_w     0.238900             0.238900
# 170  er_evap_y  mh_evap_w_lag1     0.203926             0.203926
# 171  er_evap_y        er_pcp_w     0.191188             0.191188
# 172  er_evap_y       on_evap_l    -0.185634             0.185634
# 173  er_evap_y        su_pcp_w    -0.174119             0.174119
# 174  er_evap_y        mh_pcp_w    -0.172689             0.172689
# 175  er_evap_y   on_pcp_l_lag1     0.149554             0.149554
# 176  er_evap_y       mh_evap_w    -0.140404             0.140404
# 177  er_evap_y  on_evap_l_lag1    -0.134153             0.134153
# 178  er_evap_y       on_evap_w     0.130875             0.130875
# 179  er_evap_y        on_pcp_l     0.126375             0.126375
# 180  er_evap_y   er_pcp_l_lag1    -0.125830             0.125830
# 181  er_evap_y   mh_pcp_l_lag1     0.107608             0.107608
# 182  er_evap_y   on_pcp_w_lag1    -0.091620             0.091620
# 183  er_evap_y   su_pcp_l_lag1     0.083453             0.083453
# 184  er_evap_y  su_evap_w_lag1    -0.077740             0.077740
# 185  er_evap_y   su_tmp_l_lag1     0.066621             0.066621
# 186  er_evap_y   mh_pcp_w_lag1    -0.065694             0.065694
# 187  er_evap_y        on_pcp_w    -0.050666             0.050666
# 188  er_evap_y  er_evap_l_lag1     0.047744             0.047744
# 189  er_evap_y   er_pcp_w_lag1     0.031522             0.031522
# 190  er_evap_y   su_pcp_w_lag1     0.021261             0.021261
# 191  er_evap_y       su_evap_l    -0.011024             0.011024
# 192  er_precip   mh_tmp_w_lag1    -6.449037             6.449037
# 193  er_precip   mh_tmp_l_lag1     6.019632             6.019632
# 194  er_precip        er_tmp_w     5.313140             5.313140
# 195  er_precip        mh_tmp_w    -5.122290             5.122290
# 196  er_precip   on_tmp_w_lag1     4.756559             4.756559
# 197  er_precip        er_tmp_l    -3.865238             3.865238
# 198  er_precip        on_tmp_l     3.624612             3.624612
# 199  er_precip        mh_tmp_l    -3.271701             3.271701
# 200  er_precip   su_tmp_l_lag1    -3.260563             3.260563
# 201  er_precip   su_tmp_w_lag1     3.211336             3.211336
# 202  er_precip   er_tmp_l_lag1    -2.527482             2.527482
# 203  er_precip   on_tmp_l_lag1    -2.479343             2.479343
# 204  er_precip        su_tmp_l     2.303297             2.303297
# 205  er_precip        on_tmp_w     1.605123             1.605123
# 206  er_precip   er_tmp_w_lag1     1.480645             1.480645
# 207  er_precip       mh_evap_l    -0.787852             0.787852
# 208  er_precip  er_evap_l_lag1     0.553678             0.553678
# 209  er_precip  su_evap_l_lag1     0.550726             0.550726
# 210  er_precip        mh_pcp_l    -0.509187             0.509187
# 211  er_precip  on_evap_l_lag1    -0.480789             0.480789
# 212  er_precip        mh_pcp_w     0.454064             0.454064
# 213  er_precip   mh_pcp_w_lag1     0.412869             0.412869
# 214  er_precip   mh_pcp_l_lag1    -0.411269             0.411269
# 215  er_precip       on_evap_l     0.395139             0.395139
# 216  er_precip        er_pcp_w     0.374659             0.374659
# 217  er_precip  mh_evap_w_lag1    -0.359751             0.359751
# 218  er_precip        er_pcp_l     0.339255             0.339255
# 219  er_precip       er_evap_w    -0.272806             0.272806
# 220  er_precip  mh_evap_l_lag1    -0.242652             0.242652
# 221  er_precip       on_evap_w     0.210140             0.210140
# 222  er_precip       su_evap_w    -0.166851             0.166851
# 223  er_precip   su_pcp_w_lag1    -0.150081             0.150081
# 224  er_precip        su_tmp_w    -0.095866             0.095866
# 225  er_precip  er_evap_w_lag1     0.084090             0.084090
# 226  er_precip       su_evap_l    -0.082674             0.082674
# 227  er_precip        on_pcp_w     0.082161             0.082161
# 228  er_precip        su_pcp_w     0.074095             0.074095
# 229  er_precip        on_pcp_l    -0.072382             0.072382
# 230  er_precip   su_pcp_l_lag1     0.068558             0.068558
# 231  er_precip        su_pcp_l    -0.057308             0.057308
# 232  er_precip  on_evap_w_lag1     0.030986             0.030986
# 233  er_precip  su_evap_w_lag1     0.027392             0.027392
# 234  er_precip       mh_evap_w     0.027002             0.027002
# 235  er_precip   on_pcp_l_lag1    -0.023115             0.023115
# 236  er_precip   er_pcp_l_lag1    -0.022903             0.022903
# 237  er_precip   er_pcp_w_lag1    -0.019305             0.019305
# 238  er_precip   on_pcp_w_lag1     0.018359             0.018359
# 239  er_precip       er_evap_l     0.008954             0.008954
# 240  er_runoff   on_tmp_l_lag1    -8.680189             8.680189
# 241  er_runoff   mh_tmp_w_lag1    -7.322556             7.322556
# 242  er_runoff   er_tmp_w_lag1     6.093603             6.093603
# 243  er_runoff   on_tmp_w_lag1     5.663911             5.663911
# 244  er_runoff        er_tmp_w    -5.526304             5.526304
# 245  er_runoff        er_tmp_l     5.101013             5.101013
# 246  er_runoff        on_tmp_l     5.083242             5.083242
# 247  er_runoff   mh_tmp_l_lag1    -4.198921             4.198921
# 248  er_runoff   er_tmp_l_lag1     4.023326             4.023326
# 249  er_runoff   su_tmp_w_lag1     3.546867             3.546867
# 250  er_runoff        mh_tmp_l    -2.519752             2.519752
# 251  er_runoff        on_tmp_w     2.121317             2.121317
# 252  er_runoff        su_tmp_l    -1.631720             1.631720
# 253  er_runoff        mh_tmp_w    -1.193866             1.193866
# 254  er_runoff   su_tmp_l_lag1     0.843751             0.843751
# 255  er_runoff       er_evap_l    -0.516942             0.516942
# 256  er_runoff        er_pcp_l     0.473216             0.473216
# 257  er_runoff  on_evap_w_lag1    -0.470414             0.470414
# 258  er_runoff       mh_evap_l    -0.307939             0.307939
# 259  er_runoff       er_evap_w    -0.296898             0.296898
# 260  er_runoff  er_evap_l_lag1     0.287765             0.287765
# 261  er_runoff  on_evap_l_lag1    -0.285882             0.285882
# 262  er_runoff  mh_evap_l_lag1    -0.282295             0.282295
# 263  er_runoff       su_evap_w    -0.276789             0.276789
# 264  er_runoff       on_evap_w     0.236817             0.236817
# 265  er_runoff   mh_pcp_l_lag1    -0.219238             0.219238
# 266  er_runoff   mh_pcp_w_lag1     0.195083             0.195083
# 267  er_runoff   su_pcp_l_lag1     0.143699             0.143699
# 268  er_runoff   er_pcp_l_lag1     0.130259             0.130259
# 269  er_runoff        mh_pcp_w     0.129925             0.129925
# 270  er_runoff  er_evap_w_lag1    -0.126842             0.126842
# 271  er_runoff       mh_evap_w     0.125556             0.125556
# 272  er_runoff   on_pcp_l_lag1    -0.110646             0.110646
# 273  er_runoff   on_pcp_w_lag1     0.101165             0.101165
# 274  er_runoff  su_evap_l_lag1     0.083332             0.083332
# 275  er_runoff  mh_evap_w_lag1     0.055159             0.055159
# 276  er_runoff        on_pcp_w     0.048456             0.048456
# 277  er_runoff   su_pcp_w_lag1    -0.047407             0.047407
# 278  er_runoff        su_pcp_l    -0.046632             0.046632
# 279  er_runoff        su_pcp_w    -0.045937             0.045937
# 280  er_runoff  su_evap_w_lag1     0.045219             0.045219
# 281  er_runoff        su_tmp_w     0.033082             0.033082
# 282  er_runoff        mh_pcp_l    -0.029917             0.029917
# 283  er_runoff        er_pcp_w     0.028119             0.028119
# 284  er_runoff       su_evap_l     0.021515             0.021515
# 285  er_runoff       on_evap_l    -0.015720             0.015720
# 286  er_runoff   er_pcp_w_lag1     0.011888             0.011888
# 287  er_runoff        on_pcp_l     0.004587             0.004587
# 288  on_evap_y        mh_tmp_l     6.612279             6.612279
# 289  on_evap_y        er_tmp_l    -5.649172             5.649172
# 290  on_evap_y   mh_tmp_l_lag1    -5.378701             5.378701
# 291  on_evap_y        on_tmp_w    -4.184844             4.184844
# 292  on_evap_y   mh_tmp_w_lag1     4.015799             4.015799
# 293  on_evap_y   su_tmp_w_lag1    -3.649082             3.649082
# 294  on_evap_y   su_tmp_l_lag1     3.434569             3.434569
# 295  on_evap_y   er_tmp_w_lag1     2.937423             2.937423
# 296  on_evap_y        er_tmp_w     2.639312             2.639312
# 297  on_evap_y   on_tmp_l_lag1     1.916435             1.916435
# 298  on_evap_y        su_tmp_l    -1.286961             1.286961
# 299  on_evap_y        su_tmp_w    -1.024473             1.024473
# 300  on_evap_y   er_tmp_l_lag1    -0.847089             0.847089
# 301  on_evap_y   on_tmp_w_lag1    -0.834384             0.834384
# 302  on_evap_y        mh_tmp_w     0.800044             0.800044
# 303  on_evap_y        on_tmp_l     0.750307             0.750307
# 304  on_evap_y       on_evap_w     0.575701             0.575701
# 305  on_evap_y   mh_pcp_l_lag1     0.376204             0.376204
# 306  on_evap_y       su_evap_w     0.372860             0.372860
# 307  on_evap_y   mh_pcp_w_lag1    -0.341104             0.341104
# 308  on_evap_y  su_evap_l_lag1    -0.294675             0.294675
# 309  on_evap_y        mh_pcp_l     0.211196             0.211196
# 310  on_evap_y       er_evap_w    -0.148257             0.148257
# 311  on_evap_y   er_pcp_l_lag1    -0.136918             0.136918
# 312  on_evap_y       mh_evap_l     0.134553             0.134553
# 313  on_evap_y        mh_pcp_w    -0.124144             0.124144
# 314  on_evap_y        er_pcp_l    -0.115737             0.115737
# 315  on_evap_y  on_evap_w_lag1    -0.107717             0.107717
# 316  on_evap_y   su_pcp_l_lag1     0.100069             0.100069
# 317  on_evap_y       on_evap_l    -0.100007             0.100007
# 318  on_evap_y       mh_evap_w     0.097385             0.097385
# 319  on_evap_y   on_pcp_l_lag1     0.097318             0.097318
# 320  on_evap_y   er_pcp_w_lag1     0.091955             0.091955
# 321  on_evap_y   su_pcp_w_lag1    -0.080933             0.080933
# 322  on_evap_y  on_evap_l_lag1     0.076477             0.076477
# 323  on_evap_y  er_evap_l_lag1    -0.070259             0.070259
# 324  on_evap_y        on_pcp_w     0.055639             0.055639
# 325  on_evap_y        su_pcp_l    -0.047537             0.047537
# 326  on_evap_y        er_pcp_w     0.047187             0.047187
# 327  on_evap_y   on_pcp_w_lag1    -0.043903             0.043903
# 328  on_evap_y        su_pcp_w     0.039953             0.039953
# 329  on_evap_y       su_evap_l    -0.039247             0.039247
# 330  on_evap_y  mh_evap_w_lag1     0.036001             0.036001
# 331  on_evap_y       er_evap_l    -0.035428             0.035428
# 332  on_evap_y        on_pcp_l    -0.034685             0.034685
# 333  on_evap_y  er_evap_w_lag1    -0.026236             0.026236
# 334  on_evap_y  su_evap_w_lag1     0.022595             0.022595
# 335  on_evap_y  mh_evap_l_lag1    -0.013820             0.013820
# 336  on_precip   er_tmp_l_lag1     4.018687             4.018687
# 337  on_precip   on_tmp_l_lag1    -3.948906             3.948906
# 338  on_precip        on_tmp_l     3.092621             3.092621
# 339  on_precip   on_tmp_w_lag1     2.974832             2.974832
# 340  on_precip        on_tmp_w    -2.673513             2.673513
# 341  on_precip   mh_tmp_w_lag1    -2.535313             2.535313
# 342  on_precip        su_tmp_l    -1.866217             1.866217
# 343  on_precip        mh_tmp_l     1.862302             1.862302
# 344  on_precip        er_tmp_l    -1.405216             1.405216
# 345  on_precip   mh_tmp_l_lag1     1.387105             1.387105
# 346  on_precip   su_tmp_w_lag1     1.079377             1.079377
# 347  on_precip        er_tmp_w    -0.924487             0.924487
# 348  on_precip   su_tmp_l_lag1    -0.756700             0.756700
# 349  on_precip       mh_evap_l    -0.714060             0.714060
# 350  on_precip  on_evap_l_lag1    -0.670372             0.670372
# 351  on_precip  er_evap_l_lag1     0.558940             0.558940
# 352  on_precip        su_tmp_w     0.508082             0.508082
# 353  on_precip       mh_evap_w    -0.413134             0.413134
# 354  on_precip        on_pcp_w     0.380225             0.380225
# 355  on_precip   er_tmp_w_lag1    -0.376611             0.376611
# 356  on_precip  su_evap_l_lag1     0.330774             0.330774
# 357  on_precip       on_evap_l     0.286802             0.286802
# 358  on_precip       su_evap_l     0.240884             0.240884
# 359  on_precip        on_pcp_l     0.228812             0.228812
# 360  on_precip   mh_pcp_w_lag1     0.221451             0.221451
# 361  on_precip       on_evap_w     0.220467             0.220467
# 362  on_precip        mh_tmp_w     0.213087             0.213087
# 363  on_precip        mh_pcp_w     0.176478             0.176478
# 364  on_precip       er_evap_l     0.167547             0.167547
# 365  on_precip   mh_pcp_l_lag1    -0.161515             0.161515
# 366  on_precip        su_pcp_l    -0.160888             0.160888
# 367  on_precip  er_evap_w_lag1     0.151855             0.151855
# 368  on_precip  mh_evap_w_lag1    -0.121123             0.121123
# 369  on_precip   on_pcp_l_lag1     0.104872             0.104872
# 370  on_precip   er_pcp_w_lag1    -0.096711             0.096711
# 371  on_precip   su_pcp_l_lag1    -0.090136             0.090136
# 372  on_precip  su_evap_w_lag1     0.089873             0.089873
# 373  on_precip        mh_pcp_l    -0.080548             0.080548
# 374  on_precip        su_pcp_w     0.077539             0.077539
# 375  on_precip   er_pcp_l_lag1    -0.056835             0.056835
# 376  on_precip        er_pcp_w     0.049722             0.049722
# 377  on_precip       su_evap_w     0.046378             0.046378
# 378  on_precip        er_pcp_l    -0.039398             0.039398
# 379  on_precip       er_evap_w    -0.030496             0.030496
# 380  on_precip  on_evap_w_lag1    -0.024748             0.024748
# 381  on_precip  mh_evap_l_lag1     0.024027             0.024027
# 382  on_precip   su_pcp_w_lag1     0.022096             0.022096
# 383  on_precip   on_pcp_w_lag1     0.007746             0.007746
# 384  on_runoff        on_tmp_l    32.055053            32.055053
# 385  on_runoff        on_tmp_w   -22.111570            22.111570
# 386  on_runoff   er_tmp_l_lag1    20.072181            20.072181
# 387  on_runoff   mh_tmp_l_lag1   -18.845545            18.845545
# 388  on_runoff   on_tmp_l_lag1   -18.008332            18.008332
# 389  on_runoff        mh_tmp_w    16.676445            16.676445
# 390  on_runoff        er_tmp_w   -15.205290            15.205290
# 391  on_runoff   on_tmp_w_lag1    14.499952            14.499952
# 392  on_runoff   su_tmp_l_lag1     6.369234             6.369234
# 393  on_runoff        er_tmp_l    -4.819455             4.819455
# 394  on_runoff        su_tmp_w    -4.555432             4.555432
# 395  on_runoff   mh_tmp_w_lag1    -3.877101             3.877101
# 396  on_runoff   er_tmp_w_lag1    -3.366011             3.366011
# 397  on_runoff   su_tmp_w_lag1     2.923903             2.923903
# 398  on_runoff        su_tmp_l    -2.829607             2.829607
# 399  on_runoff       su_evap_l     0.976818             0.976818
# 400  on_runoff       mh_evap_l    -0.864751             0.864751
# 401  on_runoff       mh_evap_w    -0.822835             0.822835
# 402  on_runoff        mh_tmp_l     0.747879             0.747879
# 403  on_runoff  on_evap_w_lag1    -0.699630             0.699630
# 404  on_runoff       on_evap_l    -0.666211             0.666211
# 405  on_runoff  on_evap_l_lag1    -0.569819             0.569819
# 406  on_runoff       on_evap_w     0.561980             0.561980
# 407  on_runoff   on_pcp_l_lag1     0.542693             0.542693
# 408  on_runoff        mh_pcp_w     0.431858             0.431858
# 409  on_runoff   su_pcp_l_lag1     0.332850             0.332850
# 410  on_runoff        on_pcp_l     0.311585             0.311585
# 411  on_runoff        on_pcp_w     0.309684             0.309684
# 412  on_runoff   er_pcp_w_lag1    -0.195569             0.195569
# 413  on_runoff   er_pcp_l_lag1     0.187330             0.187330
# 414  on_runoff   mh_pcp_l_lag1    -0.178636             0.178636
# 415  on_runoff       su_evap_w     0.172015             0.172015
# 416  on_runoff        su_pcp_w    -0.171705             0.171705
# 417  on_runoff  mh_evap_l_lag1    -0.168458             0.168458
# 418  on_runoff   su_pcp_w_lag1    -0.153100             0.153100
# 419  on_runoff        mh_pcp_l    -0.139098             0.139098
# 420  on_runoff       er_evap_w     0.139019             0.139019
# 421  on_runoff        er_pcp_w    -0.136961             0.136961
# 422  on_runoff  su_evap_w_lag1    -0.124249             0.124249
# 423  on_runoff        su_pcp_l     0.118216             0.118216
# 424  on_runoff        er_pcp_l     0.114456             0.114456
# 425  on_runoff   mh_pcp_w_lag1     0.081159             0.081159
# 426  on_runoff  su_evap_l_lag1    -0.067963             0.067963
# 427  on_runoff   on_pcp_w_lag1     0.058998             0.058998
# 428  on_runoff  er_evap_w_lag1     0.044132             0.044132
# 429  on_runoff  mh_evap_w_lag1    -0.034574             0.034574
# 430  on_runoff  er_evap_l_lag1    -0.029528             0.029528
# 431  on_runoff       er_evap_l     0.004877             0.004877
# 432  mh_evap_y        mh_tmp_l     8.622821             8.622821
# 433  mh_evap_y        er_tmp_l    -4.708803             4.708803
# 434  mh_evap_y        mh_tmp_w    -4.123697             4.123697
# 435  mh_evap_y        er_tmp_w    -3.303977             3.303977
# 436  mh_evap_y   er_tmp_w_lag1     3.020056             3.020056
# 437  mh_evap_y   su_tmp_l_lag1     1.790523             1.790523
# 438  mh_evap_y   on_tmp_l_lag1    -1.595897             1.595897
# 439  mh_evap_y        on_tmp_l     1.417161             1.417161
# 440  mh_evap_y        su_tmp_l    -0.914567             0.914567
# 441  mh_evap_y   on_tmp_w_lag1    -0.877982             0.877982
# 442  mh_evap_y   su_tmp_w_lag1     0.706375             0.706375
# 443  mh_evap_y  su_evap_l_lag1    -0.598072             0.598072
# 444  mh_evap_y        on_tmp_w    -0.533163             0.533163
# 445  mh_evap_y   er_tmp_l_lag1     0.517764             0.517764
# 446  mh_evap_y       su_evap_l     0.458542             0.458542
# 447  mh_evap_y       mh_evap_w     0.436889             0.436889
# 448  mh_evap_y   mh_tmp_w_lag1    -0.358624             0.358624
# 449  mh_evap_y       su_evap_w     0.276160             0.276160
# 450  mh_evap_y       on_evap_l    -0.276103             0.276103
# 451  mh_evap_y   mh_pcp_l_lag1     0.237790             0.237790
# 452  mh_evap_y   mh_tmp_l_lag1     0.224755             0.224755
# 453  mh_evap_y       er_evap_l     0.209425             0.209425
# 454  mh_evap_y       mh_evap_l    -0.206177             0.206177
# 455  mh_evap_y  er_evap_l_lag1    -0.187691             0.187691
# 456  mh_evap_y   mh_pcp_w_lag1    -0.186199             0.186199
# 457  mh_evap_y   on_pcp_l_lag1     0.178737             0.178737
# 458  mh_evap_y       on_evap_w     0.168448             0.168448
# 459  mh_evap_y  er_evap_w_lag1     0.160331             0.160331
# 460  mh_evap_y   on_pcp_w_lag1    -0.136402             0.136402
# 461  mh_evap_y  mh_evap_l_lag1     0.130037             0.130037
# 462  mh_evap_y  on_evap_w_lag1    -0.112281             0.112281
# 463  mh_evap_y  mh_evap_w_lag1     0.095227             0.095227
# 464  mh_evap_y   su_pcp_l_lag1     0.082883             0.082883
# 465  mh_evap_y  on_evap_l_lag1     0.077008             0.077008
# 466  mh_evap_y       er_evap_w    -0.076114             0.076114
# 467  mh_evap_y   er_pcp_l_lag1    -0.073053             0.073053
# 468  mh_evap_y        su_pcp_w     0.069142             0.069142
# 469  mh_evap_y        er_pcp_l    -0.057767             0.057767
# 470  mh_evap_y        mh_pcp_w    -0.051310             0.051310
# 471  mh_evap_y        su_pcp_l    -0.045836             0.045836
# 472  mh_evap_y        su_tmp_w     0.043819             0.043819
# 473  mh_evap_y  su_evap_w_lag1     0.043195             0.043195
# 474  mh_evap_y   er_pcp_w_lag1     0.043077             0.043077
# 475  mh_evap_y        er_pcp_w     0.038542             0.038542
# 476  mh_evap_y        mh_pcp_l     0.035865             0.035865
# 477  mh_evap_y        on_pcp_l     0.035683             0.035683
# 478  mh_evap_y        on_pcp_w    -0.020244             0.020244
# 479  mh_evap_y   su_pcp_w_lag1     0.006391             0.006391
# 480  mh_precip        on_tmp_w     6.257537             6.257537
# 481  mh_precip        mh_tmp_w    -5.220116             5.220116
# 482  mh_precip   mh_tmp_w_lag1    -4.125452             4.125452
# 483  mh_precip   on_tmp_w_lag1     4.100902             4.100902
# 484  mh_precip   mh_tmp_l_lag1     3.959813             3.959813
# 485  mh_precip        er_tmp_l     3.802331             3.802331
# 486  mh_precip   on_tmp_l_lag1    -3.641677             3.641677
# 487  mh_precip        on_tmp_l    -3.190923             3.190923
# 488  mh_precip        su_tmp_w     2.669037             2.669037
# 489  mh_precip   su_tmp_w_lag1    -2.288399             2.288399
# 490  mh_precip        er_tmp_w    -2.151394             2.151394
# 491  mh_precip   er_tmp_w_lag1     1.988005             1.988005
# 492  mh_precip        su_tmp_l    -1.530502             1.530502
# 493  mh_precip   er_tmp_l_lag1    -1.278453             1.278453
# 494  mh_precip   su_tmp_l_lag1     1.256537             1.256537
# 495  mh_precip        mh_pcp_w     0.677595             0.677595
# 496  mh_precip       su_evap_l    -0.330801             0.330801
# 497  mh_precip  su_evap_l_lag1     0.310820             0.310820
# 498  mh_precip   mh_pcp_w_lag1     0.309208             0.309208
# 499  mh_precip       on_evap_l     0.289329             0.289329
# 500  mh_precip  er_evap_l_lag1     0.286537             0.286537
# 501  mh_precip       mh_evap_l    -0.282561             0.282561
# 502  mh_precip       on_evap_w     0.257013             0.257013
# 503  mh_precip   mh_pcp_l_lag1    -0.249045             0.249045
# 504  mh_precip        mh_pcp_l     0.208579             0.208579
# 505  mh_precip  mh_evap_l_lag1    -0.204174             0.204174
# 506  mh_precip  mh_evap_w_lag1    -0.194234             0.194234
# 507  mh_precip  su_evap_w_lag1     0.193245             0.193245
# 508  mh_precip        mh_tmp_l     0.164462             0.164462
# 509  mh_precip  on_evap_l_lag1    -0.160118             0.160118
# 510  mh_precip       mh_evap_w    -0.160062             0.160062
# 511  mh_precip       su_evap_w    -0.130026             0.130026
# 512  mh_precip  on_evap_w_lag1    -0.096490             0.096490
# 513  mh_precip        on_pcp_l    -0.090711             0.090711
# 514  mh_precip        er_pcp_l    -0.089284             0.089284
# 515  mh_precip   su_pcp_w_lag1    -0.087556             0.087556
# 516  mh_precip  er_evap_w_lag1     0.084313             0.084313
# 517  mh_precip   su_pcp_l_lag1     0.068292             0.068292
# 518  mh_precip   er_pcp_w_lag1    -0.063318             0.063318
# 519  mh_precip        su_pcp_l    -0.054211             0.054211
# 520  mh_precip   on_pcp_l_lag1     0.053007             0.053007
# 521  mh_precip        er_pcp_w     0.049357             0.049357
# 522  mh_precip        su_pcp_w     0.037265             0.037265
# 523  mh_precip        on_pcp_w     0.035189             0.035189
# 524  mh_precip   er_pcp_l_lag1    -0.031621             0.031621
# 525  mh_precip       er_evap_w    -0.029133             0.029133
# 526  mh_precip   on_pcp_w_lag1     0.016730             0.016730
# 527  mh_precip       er_evap_l     0.011375             0.011375
# 528  mh_runoff        on_tmp_l     9.690714             9.690714
# 529  mh_runoff   on_tmp_w_lag1     7.772205             7.772205
# 530  mh_runoff        mh_tmp_l     7.718663             7.718663
# 531  mh_runoff        er_tmp_w    -6.906690             6.906690
# 532  mh_runoff        on_tmp_w    -6.226313             6.226313
# 533  mh_runoff   on_tmp_l_lag1    -5.855030             5.855030
# 534  mh_runoff   mh_tmp_w_lag1    -5.446373             5.446373
# 535  mh_runoff   mh_tmp_l_lag1    -5.419965             5.419965
# 536  mh_runoff   er_tmp_l_lag1     5.256602             5.256602
# 537  mh_runoff        er_tmp_l    -2.897028             2.897028
# 538  mh_runoff        su_tmp_l    -2.614329             2.614329
# 539  mh_runoff   su_tmp_w_lag1     2.120224             2.120224
# 540  mh_runoff   er_tmp_w_lag1     0.974361             0.974361
# 541  mh_runoff   su_tmp_l_lag1     0.707879             0.707879
# 542  mh_runoff       mh_evap_l    -0.525726             0.525726
# 543  mh_runoff        su_tmp_w     0.498806             0.498806
# 544  mh_runoff   mh_pcp_l_lag1     0.284769             0.284769
# 545  mh_runoff       er_evap_l     0.244562             0.244562
# 546  mh_runoff        mh_pcp_w     0.241370             0.241370
# 547  mh_runoff  on_evap_w_lag1    -0.226093             0.226093
# 548  mh_runoff        mh_tmp_w     0.223768             0.223768
# 549  mh_runoff       on_evap_l    -0.192897             0.192897
# 550  mh_runoff  mh_evap_l_lag1    -0.139969             0.139969
# 551  mh_runoff  su_evap_w_lag1    -0.138544             0.138544
# 552  mh_runoff   er_pcp_w_lag1     0.125236             0.125236
# 553  mh_runoff   su_pcp_l_lag1     0.123118             0.123118
# 554  mh_runoff   er_pcp_l_lag1    -0.116807             0.116807
# 555  mh_runoff        on_pcp_l    -0.106449             0.106449
# 556  mh_runoff       on_evap_w     0.103564             0.103564
# 557  mh_runoff       su_evap_w    -0.094425             0.094425
# 558  mh_runoff        mh_pcp_l     0.087091             0.087091
# 559  mh_runoff        su_pcp_l     0.074352             0.074352
# 560  mh_runoff   mh_pcp_w_lag1    -0.061159             0.061159
# 561  mh_runoff        er_pcp_l     0.058560             0.058560
# 562  mh_runoff  on_evap_l_lag1     0.053339             0.053339
# 563  mh_runoff        su_pcp_w    -0.044016             0.044016
# 564  mh_runoff  su_evap_l_lag1     0.040202             0.040202
# 565  mh_runoff   su_pcp_w_lag1    -0.038812             0.038812
# 566  mh_runoff        er_pcp_w     0.033699             0.033699
# 567  mh_runoff   on_pcp_w_lag1    -0.025296             0.025296
# 568  mh_runoff       su_evap_l     0.020695             0.020695
# 569  mh_runoff  er_evap_w_lag1    -0.019200             0.019200
# 570  mh_runoff       mh_evap_w     0.014225             0.014225
# 571  mh_runoff       er_evap_w    -0.009220             0.009220
# 572  mh_runoff  er_evap_l_lag1     0.008039             0.008039
# 573  mh_runoff   on_pcp_l_lag1    -0.002267             0.002267
# 574  mh_runoff  mh_evap_w_lag1     0.001812             0.001812
# 575  mh_runoff        on_pcp_w    -0.000931             0.000931

# %%
## Neural Network: r2 = 0.4002

# Standardize the data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Define the neural network architecture
model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(X_train.shape[1],)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(12)  # Number of targets
])

# Compile the model
model.compile(optimizer='adam', loss='mse')  # Using mean squared error (mse) as the loss function

# Fit the model to the training data
model.fit(X_train_scaled, y_train, epochs=50, batch_size=32, validation_split=0.2, verbose=1)

# Save the trained model
joblib.dump(model,'NN_trained_model.joblib')

# Predict on the test set
y_pred = model.predict(X_test_scaled)

# Calculate Mean Squared Error
mse = mean_squared_error(y_test, y_pred)
r_squared = r2_score(y_test, y_pred)
print(f"The r squared value for the model is {r_squared}")
print(f"Mean Squared Error: {mse}")
# Out:
# Epoch 1/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1869960.5000 - val_loss: 1924885.3750
# Epoch 2/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1916225.1250 - val_loss: 1924183.1250
# Epoch 3/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1858305.2500 - val_loss: 1923263.7500
# Epoch 4/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1906919.0000 - val_loss: 1921910.0000
# Epoch 5/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1808742.3750 - val_loss: 1919836.3750
# Epoch 6/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1861943.6250 - val_loss: 1916625.0000
# Epoch 7/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1873305.7500 - val_loss: 1911846.3750
# Epoch 8/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1854955.8750 - val_loss: 1904934.8750
# Epoch 9/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1896222.6250 - val_loss: 1895153.1250
# Epoch 10/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1842323.7500 - val_loss: 1881833.7500
# Epoch 11/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1802505.0000 - val_loss: 1864042.8750
# Epoch 12/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1803972.6250 - val_loss: 1841202.2500
# Epoch 13/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1701257.5000 - val_loss: 1812269.7500
# Epoch 14/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1720719.5000 - val_loss: 1776936.0000
# Epoch 15/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1680347.5000 - val_loss: 1734519.5000
# Epoch 16/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1627102.5000 - val_loss: 1685280.0000
# Epoch 17/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1623607.1250 - val_loss: 1628864.3750
# Epoch 18/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1520199.2500 - val_loss: 1566244.5000
# Epoch 19/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1471702.2500 - val_loss: 1498035.2500
# Epoch 20/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1420987.3750 - val_loss: 1425724.3750
# Epoch 21/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1287188.7500 - val_loss: 1352386.7500
# Epoch 22/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1285477.0000 - val_loss: 1277815.8750
# Epoch 23/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1192841.2500 - val_loss: 1205003.7500
# Epoch 24/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1146630.0000 - val_loss: 1136076.5000
# Epoch 25/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1036167.4375 - val_loss: 1073362.5000
# Epoch 26/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 984313.4375 - val_loss: 1016625.0000
# Epoch 27/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 955366.3125 - val_loss: 965587.9375
# Epoch 28/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 873727.8125 - val_loss: 921142.1875
# Epoch 29/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 863150.5000 - val_loss: 882647.5000
# Epoch 30/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 851816.3125 - val_loss: 849597.1875
# Epoch 31/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 765737.9375 - val_loss: 821181.6875
# Epoch 32/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 739976.6250 - val_loss: 796817.7500
# Epoch 33/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 766755.8125 - val_loss: 775108.7500
# Epoch 34/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 724459.3125 - val_loss: 756846.8750
# Epoch 35/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 706804.5625 - val_loss: 741267.8125
# Epoch 36/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 729386.1875 - val_loss: 726729.6875
# Epoch 37/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 684470.3125 - val_loss: 714582.1875
# Epoch 38/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 705821.1250 - val_loss: 703541.0625
# Epoch 39/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 659861.1875 - val_loss: 693983.8750
# Epoch 40/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 680585.8125 - val_loss: 684687.8750
# Epoch 41/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 677535.5000 - val_loss: 675804.2500
# Epoch 42/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 638788.9375 - val_loss: 667831.3750
# Epoch 43/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 617241.3125 - val_loss: 660720.3125
# Epoch 44/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 634804.5000 - val_loss: 653726.8750
# Epoch 45/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 631810.1875 - val_loss: 647367.1250
# Epoch 46/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 637037.0625 - val_loss: 640872.4375
# Epoch 47/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 616633.8125 - val_loss: 634838.7500
# Epoch 48/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 617893.5625 - val_loss: 628957.0625
# Epoch 49/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 627797.6875 - val_loss: 622992.8750
# Epoch 50/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 583975.1250 - val_loss: 617339.0000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# The r squared value for the model is -0.15938745439052582
# Mean Squared Error: 602626.7667079141

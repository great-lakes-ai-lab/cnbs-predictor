# %% [markdown]
# # Download/Pre-process CFS forecast data
# Lindsay Fitzpatrick
# ljob@umich.edu
# 08/28/2024
#
# This script reads downloads CFS forecast data from the AWS as grib2 files. It then opens the grib2 files, calculates total basin, lake, and land, precipitation, evaporation, and average 2m air temperature. These calculations are then added to the running CSV files. This script needs the following files:
#
# - GL_mask.nc
# - CFS_EVAP_forecasts_Sums.csv
# - CFS_PCP_forecasts_Sums.csv
# - CFS_TMP_forecasts_Avgs.csv

# %%
from datetime import datetime, timedelta
import os
import sys
import boto3
from botocore import UNSIGNED
from botocore.config import Config
import cfgrib
import pandas as pd
import netCDF4 as nc
import numpy as np
import shutil
import urllib.request
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# ## User Inputs

# %%
# Path to download data to
dir = 'C:/Users/fitzpatrick/Desktop/Data/test/'
# Location of the mask file
mask_file = 'C:/Users/fitzpatrick/Desktop/Data/Input/GL_mask.nc'

# Location of existing CSV files or path/name to new CSV files
tmp_csv = dir + 'CFS_TMP_forecasts_Avgs_K.csv'
evap_csv = dir + 'CFS_EVAP_forecasts_Sums_CMS.csv'
pcp_csv = dir + 'CFS_PCP_forecasts_Sums_CMS.csv'

source = 'aws' # 'aws' or 'ncei'

# IF YOU ARE CREATING NEW CSV FILES:
# Then you need to define the start and end dates
# IF YOU ARE ADDING TO EXISTING CSV FILES:
# Then these dates will be ignored and the script will automatically pull
# the last date from the existing CSV files and continue the forecast from there.
start_date = '2024-09-19'
end_date = '2024-09-22'

# %% [markdown]
# Presets
#
# These shouldn't change unless the location changes for CFS data or the user wants different files (products specifies the prefix of the files. Different files contain different variables) or a specific forecast (utc specifies the forecast time).

# %%
## Presets ##
products = ['pgb','flx']
utc = ['00','06','12','18']

# Define mask variables
mask_variables = ['eri_basin','eri_lake','eri_land',
                 'hur_basin','hur_lake','hur_land',
                 'ont_basin','ont_lake','ont_land',
                 'mic_basin','mic_lake','mic_land',
                 'sup_basin','sup_lake','sup_land']

#AWS bucket name to locate the CFS forecast
bucket_name = 'noaa-cfs-pds'

# %% [markdown]
# ## Define Functions
#
# This function goes to the AWS site and downloads the needed CFS files for a given forecast day.

# %%
def download_grb2_aws(product, bucket_name, url_path, download_dir):
    """
    Download the CFS forecast from AWS

    Parameters:
    - product: 'flx' or 'pgb'
    - bucket_name: for CFS data it is 'noaa-cfs-pds'
    - url_path: the url path to data
    - download_dir: location to download data to
    """
    num_files_downloaded = 0

    # Create a boto3 client for S3
    s3_config = Config(signature_version=UNSIGNED)
    s3 = boto3.client('s3', config=s3_config)

    # List all objects in the specified folder path
    continuation_token = None
    objects = []

    # Use a loop to handle pagination
    while True:
        list_objects_args = {'Bucket': bucket_name, 'Prefix': url_path}
        if continuation_token:
            list_objects_args['ContinuationToken'] = continuation_token

        list_objects_response = s3.list_objects_v2(**list_objects_args)

        objects.extend(list_objects_response.get('Contents', []))

        if not list_objects_response.get('IsTruncated', False):
            break

        continuation_token = list_objects_response.get('NextContinuationToken')

    # Iterate over each object and download if it ends with '.grb2'
    for obj in objects:
        key = obj['Key']
        if product in key and key.endswith('grib.grb2'): #if key.endswith('.grb2'):
            local_file_path = os.path.join(download_dir, os.path.relpath(key, url_path))

            # Ensure the directory structure exists
            os.makedirs(os.path.dirname(local_file_path), exist_ok=True)

            # Download the file
            s3.download_file(bucket_name, key, local_file_path)
            num_files_downloaded += 1

            print(f"Downloaded: {key}")

# %%
def download_grb2_ncei(product, url_path, download_dir):

    # File counter
    num_files_downloaded = 0

    try:
        response = urllib.request.urlopen(url_path)
        html_content = response.read().decode('utf-8')
        soup = BeautifulSoup(html_content, 'html.parser')
        links = soup.find_all('a', href=lambda href: href and href.startswith(product) and href.endswith('grib.grb2'))
        
        for link in links:
            file_url = url_path + link['href']
            filename = link['href'].split('/')[-1]
            file_path = os.path.join(download_dir, filename)
            urllib.request.urlretrieve(file_url, file_path)
            print(f"Downloaded: {filename}")

            num_files_downloaded += 1

    except Exception as e:
        print(f"An error occurred: {e}")

# %%
def initialize_dataframes(tmp_csv, evap_csv, pcp_csv):
    """
    Initialize new DataFrames if CSV files do not exist.
    """
    if os.path.exists(tmp_csv):
        df_tmp_forecasts = pd.read_csv(tmp_csv)
    else:
        df_tmp_forecasts = pd.DataFrame(columns=['cfs_run', 'forecast_year', 'forecast_month'] + mask_variables)
    
    if os.path.exists(evap_csv):
        df_evap_forecasts = pd.read_csv(evap_csv)
    else:
        df_evap_forecasts = pd.DataFrame(columns=['cfs_run', 'forecast_year', 'forecast_month'] + mask_variables)
    
    if os.path.exists(pcp_csv):
        df_pcp_forecasts = pd.read_csv(pcp_csv)
    else:
        df_pcp_forecasts = pd.DataFrame(columns=['cfs_run', 'forecast_year', 'forecast_month'] + mask_variables)
    
    return df_tmp_forecasts, df_evap_forecasts, df_pcp_forecasts

# %% [markdown]
# Function to grab a specific list of files based on the prefix or suffix of a file (ie. 'pgb', '.grb2')

# %%
def get_files(directory, affix, identifier):
    """
    Get a list of all GRIB2 files in the specified directory.

    Parameters:
    - directory (str): Path to the directory containing files.
    - affix (str): 'prefix' or 'suffix'
    - identifier (str):  (ie. 'pgb', 'flx', '.grb2', or '.nc')
    Returns:
    - List of file paths to the GRIB2 files.
    """
    files = []
    for file_name in os.listdir(directory):
        if affix == 'suffix': # ends with
            if file_name.endswith(identifier):
                file_path = os.path.join(directory, file_name)
                files.append(file_path)
        elif affix == 'prefix': # begins with
            if file_name.startswith(identifier):
                file_path = os.path.join(directory, file_name)
                files.append(file_path)
    return files

# %%
def create_directory(directory):
    """Create a directory if it doesn't already exist."""
    try:
        # Check if the directory already exists
        if not os.path.exists(directory):
            os.makedirs(directory)
            print(f"Directory '{directory}' created.")
        else:
            print(f"Directory '{directory}' already exists.")
    except Exception as e:
        print(f"An error occurred: {e}")

# %% [markdown]
# Function to delete the directory with CFS grb2 files because they are not needed after calculations are saved in the CSVs.

# %%
def delete_directory(directory_path):
    # Check if the directory exists
    if not os.path.isdir(directory_path):
        print(f"The directory {directory_path} does not exist.")
        return
    try:
        # Remove the entire directory tree
        shutil.rmtree(directory_path)
        print(f"Successfully deleted the directory and all its contents: {directory_path}")
    except Exception as e:
        print(f"Error deleting {directory_path}: {e}")

# %%
def check_url_exists(url):
    try:
        response = requests.head(url)
        # Check if the response is OK (status code 200)
        return response.status_code == 200
    except requests.RequestException:
        return False

# %% [markdown]
# Function to calculate the grid cell areas [m2] based on the mask file. This is needed to calculate total precipitation and evaporation because the units are [kg/m2].

# %%
def calculate_grid_cell_areas(lon, lat):
    # Calculate grid cell areas
    # Assuming lat and lon are 1D arrays
    # Convert latitude to radians

    R = 6371000.0  # Radius of Earth in meters
    lat_rad = np.radians(lat)

    # Calculate grid cell width in radians
    dlat = np.radians(lat[1] - lat[0])
    dlon = np.radians(lon[1] - lon[0])

    # Calculate area of each grid cell in square kilometers
    area = np.zeros((len(lat), len(lon)))
    for i in range(len(lat)):
        for j in range(len(lon)):
            area[i, j] = R**2 * dlat * dlon * np.cos(lat_rad[i])

    return area

# %% [markdown]
# Function to calculate evaporation based on the 2m air temperature and latent heat flux.

# %%
# ET = kg/(m^2*time^1) or 1 mm
# LE = MJ/(M^2*time^1)
# λ  = MJ/kg

# Latent heat of vaporization varies slightly with temperature. Allen et al. (1998) provides an equation 
# for calculating λ with air  temperature variation. Temperature in this case must be in degrees Celcius.

# λ=2.501−(2.361×10−3)×Temp Celcius

# so for our data with Temp in Kelvin...

# λ=2.501−((2.361×10−3)×(Temp-273.15))

# Our variable_lhf is in W/m^2 or J/(m^2*time^1). In order to convert to MJ we must multiply by 10^-6 or 
# 0.000001. Now we have lamba and variable_lhf both in terms of MJ.

# Equation below will provide an evaporation rate in kg/m2 per s. 

def calculate_evaporation(temperature_K, latent_heat):
    lamda=(2.501-(0.002361*(temperature_K-273.15)))
    evaporation_rate=((latent_heat)*0.000001)/lamda

    return evaporation_rate # kg/m2 per s

# %% [markdown]
# Function to open each of the grib2 files and calculate the total precipitation, total evaporation, and average 2m air temperature over an entire basin, land, or lake for each of the Great Lakes. This uses the mask file to calculate each of these.

# %%
def process_grib_files(download_dir, df_tmp_forecasts, df_evap_forecasts, df_pcp_forecasts, mask_lat, mask_lon, mask_ds, mask_variables, area, calculate_evaporation):
    # Find all the .grb2 files in the directory
    file_list = get_files(download_dir, 'suffix', '.grb2')
    index = len(df_tmp_forecasts) if not df_tmp_forecasts.empty else 0  # Picks up on the last line of the CSV

    for grib2_file in file_list:

        filename = os.path.basename(grib2_file)
        parts = filename.split('.')
        cfs_run = parts[2]
        date_part = parts[3]  # Assuming parts[2] is in the format YYYYMM
        forecast_year = date_part[:4]
        forecast_month = date_part[4:6]

        if filename.startswith('flxf'):

            # Open the flx file at the 2m level to pull the 2m air temperature
            flx_2mabove = cfgrib.open_dataset(grib2_file, engine='cfgrib', filter_by_keys={'typeOfLevel': 'heightAboveGround', 'level': 2})
            df_tmp_forecasts.loc[index, 'cfs_run'] = cfs_run
            df_tmp_forecasts.loc[index, 'forecast_year'] = forecast_year
            df_tmp_forecasts.loc[index, 'forecast_month'] = forecast_month
            mean2t = flx_2mabove['mean2t']

            # Cut the variable to the mask domain
            mean2t_cut = mean2t.sel(
                latitude=slice(mask_lat.max(), mask_lat.min()),
                longitude=slice(mask_lon.min(), mask_lon.max())
            )
            # Remap and upscale the variable to match the mask domain
            mean2t_remap = mean2t_cut.interp(latitude=mask_lat, longitude=mask_lon, method='linear')
            
            # Calculate mean2t for each of the mask variables (i.e., eri_lake, eri_basin, etc.)
            for mask_var in mask_variables:

                mask = mask_ds.variables[mask_var][:]
                # Take the mean over the mask area
                tmp_avg = np.mean(mean2t_remap * mask)

                df_tmp_forecasts.loc[index, mask_var] = tmp_avg.data

            ###############################################################################

            # Open the flx file again but at the surface level to pull the latent heat flux
            flx_surface = cfgrib.open_dataset(grib2_file, engine='cfgrib', filter_by_keys={'typeOfLevel': 'surface'})
            df_evap_forecasts.loc[index, 'cfs_run'] = cfs_run
            df_evap_forecasts.loc[index, 'forecast_year'] = forecast_year
            df_evap_forecasts.loc[index, 'forecast_month'] = forecast_month
            mslhf = flx_surface['mslhf']
            
            # Cut the variable to the mask domain
            mslhf_cut = mslhf.sel(
                latitude=slice(mask_lat.max(), mask_lat.min()),
                longitude=slice(mask_lon.min(), mask_lon.max())
            )
            # Remap and upscale the variable to match the mask domain
            mslhf_remap = mslhf_cut.interp(latitude=mask_lat, longitude=mask_lon, method='linear')
            
            # Calculate evaporation across the entire domain using air temp and latent heat flux
            evap = calculate_evaporation(mean2t_remap, mslhf_remap)
            
            # Calculate evaporation for each of the mask variables (i.e., eri_lake, eri_basin, etc.)
            for mask_var in mask_variables:
                
                mask = mask_ds.variables[mask_var][:]
                total_evap = (np.sum(evap * area * mask)) # Converts kg/s/m2 to kg/s
                # Convert kg/s to m³/s (assuming density of water ≈ 1000 kg/m³)
                evap_cms = total_evap / 1000.0

                df_evap_forecasts.loc[index, mask_var] = evap_cms.data

        ###############################################################################

        elif filename.startswith('pgbf'):

            # Open the pgb file at the surface level to pull the precipitation
            pgb_surface = cfgrib.open_dataset(grib2_file, engine='cfgrib', filter_by_keys={'typeOfLevel': 'surface'})
            df_pcp_forecasts.loc[index, 'cfs_run'] = cfs_run
            df_pcp_forecasts.loc[index, 'forecast_year'] = forecast_year
            df_pcp_forecasts.loc[index, 'forecast_month'] = forecast_month
            pcp = pgb_surface['tp']  # Total precipitation
            
            # Cut the variable to the mask domain
            pcp_cut = pcp.sel(
                latitude=slice(mask_lat.max(), mask_lat.min()),
                longitude=slice(mask_lon.min(), mask_lon.max())
            )
            # Remap and upscale the variable to match the mask domain
            pcp_remap = pcp_cut.interp(latitude=mask_lat, longitude=mask_lon, method='linear')
            
            for mask_var in mask_variables:
                mask = mask_ds.variables[mask_var][:]
                
                # Convert precipitation from kg/m² per 6 hours to kg/m² per second
                pcp_per_s = pcp_remap / 21600.0 # seconds in 6hrs
                total_pcp_kg_per_s = (np.sum(pcp_per_s * area * mask)) # kg/s

                # Convert kg/s to m³/s (assuming density of water ≈ 1000 kg/m³)
                total_pcp_cms = total_pcp_kg_per_s / 1000.0
                df_pcp_forecasts.loc[index, mask_var] = total_pcp_cms.data

        print(f'Done with {filename}')

        index += 1

# %% [markdown]
# ## Begin Script

# %% [markdown]
# Open the mask file. Pull the latitude and longitude to be used to cut the global variable down to just the Great Lakes domain and upscale. Also calculates area of each of the grid cells.

# %%
create_directory(dir)
# Out:
# Directory 'C:/Users/fitzpatrick/Desktop/Data/test/' already exists.

# %%
# Open existing CSVs or create empty dataframes to save to new CSVs
df_tmp_forecasts, df_evap_forecasts, df_pcp_forecasts = initialize_dataframes(tmp_csv, evap_csv, pcp_csv)

# If we are starting a new CSV, then user must input dates above to pull data
if df_tmp_forecasts.empty:
    print("Creating new csv files.")
    start_date_i = datetime.strptime(start_date, "%Y-%m-%d") # User input above
    end_date_i = datetime.strptime(end_date, "%Y-%m-%d") # User input above
else:
    # If we are adding to an existing CSV, then pull the last date from the CSV
    # and continue from there
    print("Opening existing csv files.")
    last_cfs = df_tmp_forecasts['cfs_run'].astype(str).iloc[-1][:8]
    start_date_i = datetime.strptime(last_cfs, '%Y%m%d') + timedelta(days=1)
    # Pull all the forecasts days up to yesterday (the most complete forecast)
    end_date_i = datetime.now() - timedelta(days=1)

# Check if start_date is equal to or after end_date
if start_date_i == end_date_i:
    print("The csv files are up-to-date.")
    sys.exit()  # Stop the script
elif start_date_i > end_date_i:
    print("There is an error in the input dates. Check them and try again.")
    sys.exit()  # Stop the script
else:
    print(f"Starting from: {start_date_i.strftime('%Y-%m-%d')} and continuing through: {end_date_i.strftime('%Y-%m-%d')}")

# Create a date range
date_array = pd.date_range(start=start_date_i, end=end_date_i)
# Out:
# Opening existing csv files.
# Starting from: 2024-09-20 and continuing through: 2024-09-23

# %%
# Open the mask file and calculate the grid cell areas
mask_ds = nc.Dataset(mask_file)
mask_lat = mask_ds.variables['latitude'][:]
mask_lon = mask_ds.variables['longitude'][:]
area = calculate_grid_cell_areas(mask_lon, mask_lat)

# %% [markdown]
# Begin loop to go through the user input dates. Loop creates a directory to download the CFS grib files, runs through the download_grb2_aws funtion to download and then run through the process_grib_files to do the calculations. It then saves the calculations to the CSV files, deletes the grib2 files and moves on to the next date.

# %%
for date in date_array:
    print(f"Beginning {date}.")
    YYYY = date.strftime("%Y")
    YYYYMM = date.strftime("%Y%m")
    YYYYMMDD = date.strftime("%Y%m%d")

    date = date.strftime('%Y%m%d')
    download_dir = f'{dir}{date}/CFS/'

    if not os.path.exists(download_dir):
        os.makedirs(download_dir)

    # Download the grib2 files using AWS or NCEI
    for utc_time in utc:
        for product in products:
            if source == 'aws':
                url_path = f'cfs.{date}/{utc_time}/monthly_grib_01/'
                download_grb2_aws(product, bucket_name, url_path, download_dir)
            elif source == 'ncei':
                base_url = 'https://www.ncei.noaa.gov/data/climate-forecast-system/access/operational-9-month-forecast/monthly-means/'
                url_path = f'{base_url}/{YYYY}/{YYYYMM}/{YYYYMMDD}/{YYYYMMDD}{utc_time}/'
                if not url_path or not check_url_exists(url_path):
                    print(f"No files available for {date}.")
                else:
                    download_grb2_ncei(product, url_path, download_dir)
            else:
                print('Input source does not exist. Source must be aws or ncei.')

    process_grib_files(download_dir, df_tmp_forecasts, df_evap_forecasts, df_pcp_forecasts, mask_lat, mask_lon, mask_ds, mask_variables, area, calculate_evaporation)   
    
    # Save the updated DataFrames to CSV files
    print(df_tmp_forecasts)

    df_tmp_forecasts.to_csv(tmp_csv, sep=',', index=False)
    df_evap_forecasts.to_csv(evap_csv, sep=',', index=False)
    df_pcp_forecasts.to_csv(pcp_csv, sep=',', index=False)

    # Delete downloaded grib2 files
    #delete_directory(download_dir)
    
    print(f'Done with {date}.')
# Out:
# Beginning 2024-09-20 00:00:00.
# Downloaded: pgbf.01.2024092000.202409.avrg.grib.grb2
# Downloaded: pgbf.01.2024092000.202410.avrg.grib.grb2
# Downloaded: pgbf.01.2024092000.202411.avrg.grib.grb2
# Downloaded: pgbf.01.2024092000.202412.avrg.grib.grb2
# Downloaded: pgbf.01.2024092000.202501.avrg.grib.grb2
# Downloaded: pgbf.01.2024092000.202502.avrg.grib.grb2
# Downloaded: pgbf.01.2024092000.202503.avrg.grib.grb2
# Downloaded: pgbf.01.2024092000.202504.avrg.grib.grb2
# Downloaded: pgbf.01.2024092000.202505.avrg.grib.grb2
# Downloaded: pgbf.01.2024092000.202506.avrg.grib.grb2
# Downloaded: flxf.01.2024092000.202409.avrg.grib.grb2
# Downloaded: flxf.01.2024092000.202410.avrg.grib.grb2
# Downloaded: flxf.01.2024092000.202411.avrg.grib.grb2
# Downloaded: flxf.01.2024092000.202412.avrg.grib.grb2
# Downloaded: flxf.01.2024092000.202501.avrg.grib.grb2
# Downloaded: flxf.01.2024092000.202502.avrg.grib.grb2
# Downloaded: flxf.01.2024092000.202503.avrg.grib.grb2
# Downloaded: flxf.01.2024092000.202504.avrg.grib.grb2
# Downloaded: flxf.01.2024092000.202505.avrg.grib.grb2
# Downloaded: flxf.01.2024092000.202506.avrg.grib.grb2
# Downloaded: pgbf.01.2024092006.202409.avrg.grib.grb2
# Downloaded: pgbf.01.2024092006.202410.avrg.grib.grb2
# Downloaded: pgbf.01.2024092006.202411.avrg.grib.grb2
# Downloaded: pgbf.01.2024092006.202412.avrg.grib.grb2
# Downloaded: pgbf.01.2024092006.202501.avrg.grib.grb2
# Downloaded: pgbf.01.2024092006.202502.avrg.grib.grb2
# Downloaded: pgbf.01.2024092006.202503.avrg.grib.grb2
# Downloaded: pgbf.01.2024092006.202504.avrg.grib.grb2
# Downloaded: pgbf.01.2024092006.202505.avrg.grib.grb2
# Downloaded: pgbf.01.2024092006.202506.avrg.grib.grb2
# Downloaded: flxf.01.2024092006.202409.avrg.grib.grb2
# Downloaded: flxf.01.2024092006.202410.avrg.grib.grb2
# Downloaded: flxf.01.2024092006.202411.avrg.grib.grb2
# Downloaded: flxf.01.2024092006.202412.avrg.grib.grb2
# Downloaded: flxf.01.2024092006.202501.avrg.grib.grb2
# Downloaded: flxf.01.2024092006.202502.avrg.grib.grb2
# Downloaded: flxf.01.2024092006.202503.avrg.grib.grb2
# Downloaded: flxf.01.2024092006.202504.avrg.grib.grb2
# Downloaded: flxf.01.2024092006.202505.avrg.grib.grb2
# Downloaded: flxf.01.2024092006.202506.avrg.grib.grb2
# Downloaded: pgbf.01.2024092012.202409.avrg.grib.grb2
# Downloaded: pgbf.01.2024092012.202410.avrg.grib.grb2
# Downloaded: pgbf.01.2024092012.202411.avrg.grib.grb2
# Downloaded: pgbf.01.2024092012.202412.avrg.grib.grb2
# Downloaded: pgbf.01.2024092012.202501.avrg.grib.grb2
# Downloaded: pgbf.01.2024092012.202502.avrg.grib.grb2
# Downloaded: pgbf.01.2024092012.202503.avrg.grib.grb2
# Downloaded: pgbf.01.2024092012.202504.avrg.grib.grb2
# Downloaded: pgbf.01.2024092012.202505.avrg.grib.grb2
# Downloaded: pgbf.01.2024092012.202506.avrg.grib.grb2
# Downloaded: flxf.01.2024092012.202409.avrg.grib.grb2
# Downloaded: flxf.01.2024092012.202410.avrg.grib.grb2
# Downloaded: flxf.01.2024092012.202411.avrg.grib.grb2
# Downloaded: flxf.01.2024092012.202412.avrg.grib.grb2
# Downloaded: flxf.01.2024092012.202501.avrg.grib.grb2
# Downloaded: flxf.01.2024092012.202502.avrg.grib.grb2
# Downloaded: flxf.01.2024092012.202503.avrg.grib.grb2
# Downloaded: flxf.01.2024092012.202504.avrg.grib.grb2
# Downloaded: flxf.01.2024092012.202505.avrg.grib.grb2
# Downloaded: flxf.01.2024092012.202506.avrg.grib.grb2
# Downloaded: pgbf.01.2024092018.202409.avrg.grib.grb2
# Downloaded: pgbf.01.2024092018.202410.avrg.grib.grb2
# Downloaded: pgbf.01.2024092018.202411.avrg.grib.grb2
# Downloaded: pgbf.01.2024092018.202412.avrg.grib.grb2
# Downloaded: pgbf.01.2024092018.202501.avrg.grib.grb2
# Downloaded: pgbf.01.2024092018.202502.avrg.grib.grb2
# Downloaded: pgbf.01.2024092018.202503.avrg.grib.grb2
# Downloaded: pgbf.01.2024092018.202504.avrg.grib.grb2
# Downloaded: pgbf.01.2024092018.202505.avrg.grib.grb2
# Downloaded: pgbf.01.2024092018.202506.avrg.grib.grb2
# Downloaded: flxf.01.2024092018.202409.avrg.grib.grb2
# Downloaded: flxf.01.2024092018.202410.avrg.grib.grb2
# Downloaded: flxf.01.2024092018.202411.avrg.grib.grb2
# Downloaded: flxf.01.2024092018.202412.avrg.grib.grb2
# Downloaded: flxf.01.2024092018.202501.avrg.grib.grb2
# Downloaded: flxf.01.2024092018.202502.avrg.grib.grb2
# Downloaded: flxf.01.2024092018.202503.avrg.grib.grb2
# Downloaded: flxf.01.2024092018.202504.avrg.grib.grb2
# Downloaded: flxf.01.2024092018.202505.avrg.grib.grb2
# Downloaded: flxf.01.2024092018.202506.avrg.grib.grb2
# C:\Users\fitzpatrick\AppData\Local\Temp\1\ipykernel_14876\4153316585.py:19: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2024092000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_tmp_forecasts.loc[index, 'cfs_run'] = cfs_run
# C:\Users\fitzpatrick\AppData\Local\Temp\1\ipykernel_14876\4153316585.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2024' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_tmp_forecasts.loc[index, 'forecast_year'] = forecast_year
# C:\Users\fitzpatrick\AppData\Local\Temp\1\ipykernel_14876\4153316585.py:21: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '09' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_tmp_forecasts.loc[index, 'forecast_month'] = forecast_month
# C:\Users\fitzpatrick\AppData\Local\Temp\1\ipykernel_14876\4153316585.py:45: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2024092000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_evap_forecasts.loc[index, 'cfs_run'] = cfs_run
# C:\Users\fitzpatrick\AppData\Local\Temp\1\ipykernel_14876\4153316585.py:46: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2024' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_evap_forecasts.loc[index, 'forecast_year'] = forecast_year
# C:\Users\fitzpatrick\AppData\Local\Temp\1\ipykernel_14876\4153316585.py:47: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '09' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_evap_forecasts.loc[index, 'forecast_month'] = forecast_month
# Done with flxf.01.2024092000.202409.avrg.grib.grb2
# Done with flxf.01.2024092000.202410.avrg.grib.grb2
# Done with flxf.01.2024092000.202411.avrg.grib.grb2
# Done with flxf.01.2024092000.202412.avrg.grib.grb2
# Done with flxf.01.2024092000.202501.avrg.grib.grb2
# Done with flxf.01.2024092000.202502.avrg.grib.grb2
# Done with flxf.01.2024092000.202503.avrg.grib.grb2
# Done with flxf.01.2024092000.202504.avrg.grib.grb2
# Done with flxf.01.2024092000.202505.avrg.grib.grb2
# Done with flxf.01.2024092000.202506.avrg.grib.grb2
# Done with flxf.01.2024092006.202409.avrg.grib.grb2
# Done with flxf.01.2024092006.202410.avrg.grib.grb2
# Done with flxf.01.2024092006.202411.avrg.grib.grb2
# Done with flxf.01.2024092006.202412.avrg.grib.grb2
# Done with flxf.01.2024092006.202501.avrg.grib.grb2
# Done with flxf.01.2024092006.202502.avrg.grib.grb2
# Done with flxf.01.2024092006.202503.avrg.grib.grb2
# Done with flxf.01.2024092006.202504.avrg.grib.grb2
# Done with flxf.01.2024092006.202505.avrg.grib.grb2
# Done with flxf.01.2024092006.202506.avrg.grib.grb2
# Done with flxf.01.2024092012.202409.avrg.grib.grb2
# Done with flxf.01.2024092012.202410.avrg.grib.grb2
# Done with flxf.01.2024092012.202411.avrg.grib.grb2
# Done with flxf.01.2024092012.202412.avrg.grib.grb2
# Done with flxf.01.2024092012.202501.avrg.grib.grb2
# Done with flxf.01.2024092012.202502.avrg.grib.grb2
# Done with flxf.01.2024092012.202503.avrg.grib.grb2
# Done with flxf.01.2024092012.202504.avrg.grib.grb2
# Done with flxf.01.2024092012.202505.avrg.grib.grb2
# Done with flxf.01.2024092012.202506.avrg.grib.grb2
# Done with flxf.01.2024092018.202409.avrg.grib.grb2
# Done with flxf.01.2024092018.202410.avrg.grib.grb2
# Done with flxf.01.2024092018.202411.avrg.grib.grb2
# Done with flxf.01.2024092018.202412.avrg.grib.grb2
# Done with flxf.01.2024092018.202501.avrg.grib.grb2
# Done with flxf.01.2024092018.202502.avrg.grib.grb2
# Done with flxf.01.2024092018.202503.avrg.grib.grb2
# Done with flxf.01.2024092018.202504.avrg.grib.grb2
# Done with flxf.01.2024092018.202505.avrg.grib.grb2
# Done with flxf.01.2024092018.202506.avrg.grib.grb2
# C:\Users\fitzpatrick\AppData\Local\Temp\1\ipykernel_14876\4153316585.py:77: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2024092000' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_pcp_forecasts.loc[index, 'cfs_run'] = cfs_run
# C:\Users\fitzpatrick\AppData\Local\Temp\1\ipykernel_14876\4153316585.py:78: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2024' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_pcp_forecasts.loc[index, 'forecast_year'] = forecast_year
# C:\Users\fitzpatrick\AppData\Local\Temp\1\ipykernel_14876\4153316585.py:79: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '09' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_pcp_forecasts.loc[index, 'forecast_month'] = forecast_month
# Done with pgbf.01.2024092000.202409.avrg.grib.grb2
# Done with pgbf.01.2024092000.202410.avrg.grib.grb2
# Done with pgbf.01.2024092000.202411.avrg.grib.grb2
# Done with pgbf.01.2024092000.202412.avrg.grib.grb2
# Done with pgbf.01.2024092000.202501.avrg.grib.grb2
# Done with pgbf.01.2024092000.202502.avrg.grib.grb2
# Done with pgbf.01.2024092000.202503.avrg.grib.grb2
# Done with pgbf.01.2024092000.202504.avrg.grib.grb2
# Done with pgbf.01.2024092000.202505.avrg.grib.grb2
# Done with pgbf.01.2024092000.202506.avrg.grib.grb2
# Done with pgbf.01.2024092006.202409.avrg.grib.grb2
# Done with pgbf.01.2024092006.202410.avrg.grib.grb2
# Done with pgbf.01.2024092006.202411.avrg.grib.grb2
# Done with pgbf.01.2024092006.202412.avrg.grib.grb2
# Done with pgbf.01.2024092006.202501.avrg.grib.grb2
# Done with pgbf.01.2024092006.202502.avrg.grib.grb2
# Done with pgbf.01.2024092006.202503.avrg.grib.grb2
# Done with pgbf.01.2024092006.202504.avrg.grib.grb2
# Done with pgbf.01.2024092006.202505.avrg.grib.grb2
# Done with pgbf.01.2024092006.202506.avrg.grib.grb2
# Done with pgbf.01.2024092012.202409.avrg.grib.grb2
# Done with pgbf.01.2024092012.202410.avrg.grib.grb2
# Done with pgbf.01.2024092012.202411.avrg.grib.grb2
# Done with pgbf.01.2024092012.202412.avrg.grib.grb2
# Done with pgbf.01.2024092012.202501.avrg.grib.grb2
# Done with pgbf.01.2024092012.202502.avrg.grib.grb2
# Done with pgbf.01.2024092012.202503.avrg.grib.grb2
# Done with pgbf.01.2024092012.202504.avrg.grib.grb2
# Done with pgbf.01.2024092012.202505.avrg.grib.grb2
# Done with pgbf.01.2024092012.202506.avrg.grib.grb2
# Done with pgbf.01.2024092018.202409.avrg.grib.grb2
# Done with pgbf.01.2024092018.202410.avrg.grib.grb2
# Done with pgbf.01.2024092018.202411.avrg.grib.grb2
# Done with pgbf.01.2024092018.202412.avrg.grib.grb2
# Done with pgbf.01.2024092018.202501.avrg.grib.grb2
# Done with pgbf.01.2024092018.202502.avrg.grib.grb2
# Done with pgbf.01.2024092018.202503.avrg.grib.grb2
# Done with pgbf.01.2024092018.202504.avrg.grib.grb2
# Done with pgbf.01.2024092018.202505.avrg.grib.grb2
# Done with pgbf.01.2024092018.202506.avrg.grib.grb2
#           cfs_run forecast_year forecast_month   eri_basin    eri_lake  \
# 0    2024091800.0        2024.0            9.0  290.438022  290.718765
# 1    2024091800.0        2024.0           10.0  285.436517  285.765962
# 2    2024091800.0        2024.0           11.0  280.460295  280.774295
# 3    2024091800.0        2024.0           12.0  270.470198  271.444908
# 4    2024091800.0        2025.0            1.0  265.423315  266.663449
# ..            ...           ...            ...         ...         ...
# 115    2024092018          2025             02  258.485872  260.196592
# 116    2024092018          2025             03  270.018525  270.277767
# 117    2024092018          2025             04  275.848986  275.322468
# 118    2024092018          2025             05  284.318095  283.472607
# 119    2024092018          2025             06  288.879675  287.842961
#
#        eri_land   hur_basin    hur_lake    hur_land   ont_basin    ont_lake  \
# 0    290.309809  289.113874  289.907766  288.763333  289.479747  289.868897
# 1    285.267796  284.379244  285.210733  283.985568  284.699075  285.094322
# 2    280.328485  278.316102  279.490707  277.853653  279.286362  279.699465
# 3    270.130681  268.791377  270.290871  268.038141  270.555915  270.876048
# 4    264.926454  263.886930  266.480728  262.609640  264.560120  265.335502
# ..          ...         ...         ...         ...         ...         ...
# 115  257.810789  259.333092  262.096986  257.791836  260.414312  261.120562
# 116  269.928993  265.913176  268.207306  264.960213  265.272632  266.089256
# 117  276.142592  271.018395  272.661653  270.503531  271.302129  272.011262
# 118  284.759798  281.855514  281.926247  282.068877  282.902278  282.919338
# 119  289.374102  285.784022  285.589377  286.223628  287.564536  287.497016
#
#        ont_land   mic_basin    mic_lake    mic_land   sup_basin    sup_lake  \
# 0    289.158039  289.392105  289.870566  289.155290  287.871490  287.950658
# 1    284.307262  284.470322  284.832567  284.248385  282.965611  283.611611
# 2    278.987495  278.848394  279.357636  278.615828  275.649311  276.960539
# 3    270.381804  266.628660  266.959405  266.250247  262.904641  265.422968
# 4    264.175499  263.276560  263.767776  262.685149  259.495544  262.700955
# ..          ...         ...         ...         ...         ...         ...
# 115  259.842389  256.325658  257.042622  255.471048  253.888167  257.355516
# 116  265.095106  270.238787  270.954089  269.868651  266.032390  268.106546
# 117  271.137716  275.561927  276.389263  275.397782  269.841516  271.341647
# 118  283.039965  283.933320  284.238843  284.089854  280.539638  279.910473
# 119  287.717689  288.334324  288.620595  288.629868  284.127311  282.753360
#
#        sup_land
# 0    287.796153
# 1    282.458642
# 2    274.676879
# 3    261.029587
# 4    257.090507
# ..          ...
# 115  251.191172
# 116  264.539123
# 117  268.804641
# 118  281.031706
# 119  285.210815
#
# [120 rows x 18 columns]
# Done with 20240920.
# Beginning 2024-09-21 00:00:00.
# No files available for 20240921.
# No files available for 20240921.
# No files available for 20240921.
# No files available for 20240921.
# No files available for 20240921.
# No files available for 20240921.
# No files available for 20240921.
# No files available for 20240921.
#           cfs_run forecast_year forecast_month   eri_basin    eri_lake  \
# 0    2024091800.0        2024.0            9.0  290.438022  290.718765
# 1    2024091800.0        2024.0           10.0  285.436517  285.765962
# 2    2024091800.0        2024.0           11.0  280.460295  280.774295
# 3    2024091800.0        2024.0           12.0  270.470198  271.444908
# 4    2024091800.0        2025.0            1.0  265.423315  266.663449
# ..            ...           ...            ...         ...         ...
# 115    2024092018          2025             02  258.485872  260.196592
# 116    2024092018          2025             03  270.018525  270.277767
# 117    2024092018          2025             04  275.848986  275.322468
# 118    2024092018          2025             05  284.318095  283.472607
# 119    2024092018          2025             06  288.879675  287.842961
#
#        eri_land   hur_basin    hur_lake    hur_land   ont_basin    ont_lake  \
# 0    290.309809  289.113874  289.907766  288.763333  289.479747  289.868897
# 1    285.267796  284.379244  285.210733  283.985568  284.699075  285.094322
# 2    280.328485  278.316102  279.490707  277.853653  279.286362  279.699465
# 3    270.130681  268.791377  270.290871  268.038141  270.555915  270.876048
# 4    264.926454  263.886930  266.480728  262.609640  264.560120  265.335502
# ..          ...         ...         ...         ...         ...         ...
# 115  257.810789  259.333092  262.096986  257.791836  260.414312  261.120562
# 116  269.928993  265.913176  268.207306  264.960213  265.272632  266.089256
# 117  276.142592  271.018395  272.661653  270.503531  271.302129  272.011262
# 118  284.759798  281.855514  281.926247  282.068877  282.902278  282.919338
# 119  289.374102  285.784022  285.589377  286.223628  287.564536  287.497016
#
#        ont_land   mic_basin    mic_lake    mic_land   sup_basin    sup_lake  \
# 0    289.158039  289.392105  289.870566  289.155290  287.871490  287.950658
# 1    284.307262  284.470322  284.832567  284.248385  282.965611  283.611611
# 2    278.987495  278.848394  279.357636  278.615828  275.649311  276.960539
# 3    270.381804  266.628660  266.959405  266.250247  262.904641  265.422968
# 4    264.175499  263.276560  263.767776  262.685149  259.495544  262.700955
# ..          ...         ...         ...         ...         ...         ...
# 115  259.842389  256.325658  257.042622  255.471048  253.888167  257.355516
# 116  265.095106  270.238787  270.954089  269.868651  266.032390  268.106546
# 117  271.137716  275.561927  276.389263  275.397782  269.841516  271.341647
# 118  283.039965  283.933320  284.238843  284.089854  280.539638  279.910473
# 119  287.717689  288.334324  288.620595  288.629868  284.127311  282.753360
#
#        sup_land
# 0    287.796153
# 1    282.458642
# 2    274.676879
# 3    261.029587
# 4    257.090507
# ..          ...
# 115  251.191172
# 116  264.539123
# 117  268.804641
# 118  281.031706
# 119  285.210815
#
# [120 rows x 18 columns]
# Done with 20240921.
# Beginning 2024-09-22 00:00:00.
# No files available for 20240922.
# No files available for 20240922.
# No files available for 20240922.
# No files available for 20240922.
# No files available for 20240922.
# No files available for 20240922.
# No files available for 20240922.
# No files available for 20240922.
#           cfs_run forecast_year forecast_month   eri_basin    eri_lake  \
# 0    2024091800.0        2024.0            9.0  290.438022  290.718765
# 1    2024091800.0        2024.0           10.0  285.436517  285.765962
# 2    2024091800.0        2024.0           11.0  280.460295  280.774295
# 3    2024091800.0        2024.0           12.0  270.470198  271.444908
# 4    2024091800.0        2025.0            1.0  265.423315  266.663449
# ..            ...           ...            ...         ...         ...
# 115    2024092018          2025             02  258.485872  260.196592
# 116    2024092018          2025             03  270.018525  270.277767
# 117    2024092018          2025             04  275.848986  275.322468
# 118    2024092018          2025             05  284.318095  283.472607
# 119    2024092018          2025             06  288.879675  287.842961
#
#        eri_land   hur_basin    hur_lake    hur_land   ont_basin    ont_lake  \
# 0    290.309809  289.113874  289.907766  288.763333  289.479747  289.868897
# 1    285.267796  284.379244  285.210733  283.985568  284.699075  285.094322
# 2    280.328485  278.316102  279.490707  277.853653  279.286362  279.699465
# 3    270.130681  268.791377  270.290871  268.038141  270.555915  270.876048
# 4    264.926454  263.886930  266.480728  262.609640  264.560120  265.335502
# ..          ...         ...         ...         ...         ...         ...
# 115  257.810789  259.333092  262.096986  257.791836  260.414312  261.120562
# 116  269.928993  265.913176  268.207306  264.960213  265.272632  266.089256
# 117  276.142592  271.018395  272.661653  270.503531  271.302129  272.011262
# 118  284.759798  281.855514  281.926247  282.068877  282.902278  282.919338
# 119  289.374102  285.784022  285.589377  286.223628  287.564536  287.497016
#
#        ont_land   mic_basin    mic_lake    mic_land   sup_basin    sup_lake  \
# 0    289.158039  289.392105  289.870566  289.155290  287.871490  287.950658
# 1    284.307262  284.470322  284.832567  284.248385  282.965611  283.611611
# 2    278.987495  278.848394  279.357636  278.615828  275.649311  276.960539
# 3    270.381804  266.628660  266.959405  266.250247  262.904641  265.422968
# 4    264.175499  263.276560  263.767776  262.685149  259.495544  262.700955
# ..          ...         ...         ...         ...         ...         ...
# 115  259.842389  256.325658  257.042622  255.471048  253.888167  257.355516
# 116  265.095106  270.238787  270.954089  269.868651  266.032390  268.106546
# 117  271.137716  275.561927  276.389263  275.397782  269.841516  271.341647
# 118  283.039965  283.933320  284.238843  284.089854  280.539638  279.910473
# 119  287.717689  288.334324  288.620595  288.629868  284.127311  282.753360
#
#        sup_land
# 0    287.796153
# 1    282.458642
# 2    274.676879
# 3    261.029587
# 4    257.090507
# ..          ...
# 115  251.191172
# 116  264.539123
# 117  268.804641
# 118  281.031706
# 119  285.210815
#
# [120 rows x 18 columns]
# Done with 20240922.
# Beginning 2024-09-23 00:00:00.
# No files available for 20240923.
# No files available for 20240923.
# No files available for 20240923.
# No files available for 20240923.
# No files available for 20240923.
# No files available for 20240923.
# No files available for 20240923.
# No files available for 20240923.
#           cfs_run forecast_year forecast_month   eri_basin    eri_lake  \
# 0    2024091800.0        2024.0            9.0  290.438022  290.718765
# 1    2024091800.0        2024.0           10.0  285.436517  285.765962
# 2    2024091800.0        2024.0           11.0  280.460295  280.774295
# 3    2024091800.0        2024.0           12.0  270.470198  271.444908
# 4    2024091800.0        2025.0            1.0  265.423315  266.663449
# ..            ...           ...            ...         ...         ...
# 115    2024092018          2025             02  258.485872  260.196592
# 116    2024092018          2025             03  270.018525  270.277767
# 117    2024092018          2025             04  275.848986  275.322468
# 118    2024092018          2025             05  284.318095  283.472607
# 119    2024092018          2025             06  288.879675  287.842961
#
#        eri_land   hur_basin    hur_lake    hur_land   ont_basin    ont_lake  \
# 0    290.309809  289.113874  289.907766  288.763333  289.479747  289.868897
# 1    285.267796  284.379244  285.210733  283.985568  284.699075  285.094322
# 2    280.328485  278.316102  279.490707  277.853653  279.286362  279.699465
# 3    270.130681  268.791377  270.290871  268.038141  270.555915  270.876048
# 4    264.926454  263.886930  266.480728  262.609640  264.560120  265.335502
# ..          ...         ...         ...         ...         ...         ...
# 115  257.810789  259.333092  262.096986  257.791836  260.414312  261.120562
# 116  269.928993  265.913176  268.207306  264.960213  265.272632  266.089256
# 117  276.142592  271.018395  272.661653  270.503531  271.302129  272.011262
# 118  284.759798  281.855514  281.926247  282.068877  282.902278  282.919338
# 119  289.374102  285.784022  285.589377  286.223628  287.564536  287.497016
#
#        ont_land   mic_basin    mic_lake    mic_land   sup_basin    sup_lake  \
# 0    289.158039  289.392105  289.870566  289.155290  287.871490  287.950658
# 1    284.307262  284.470322  284.832567  284.248385  282.965611  283.611611
# 2    278.987495  278.848394  279.357636  278.615828  275.649311  276.960539
# 3    270.381804  266.628660  266.959405  266.250247  262.904641  265.422968
# 4    264.175499  263.276560  263.767776  262.685149  259.495544  262.700955
# ..          ...         ...         ...         ...         ...         ...
# 115  259.842389  256.325658  257.042622  255.471048  253.888167  257.355516
# 116  265.095106  270.238787  270.954089  269.868651  266.032390  268.106546
# 117  271.137716  275.561927  276.389263  275.397782  269.841516  271.341647
# 118  283.039965  283.933320  284.238843  284.089854  280.539638  279.910473
# 119  287.717689  288.334324  288.620595  288.629868  284.127311  282.753360
#
#        sup_land
# 0    287.796153
# 1    282.458642
# 2    274.676879
# 3    261.029587
# 4    257.090507
# ..          ...
# 115  251.191172
# 116  264.539123
# 117  268.804641
# 118  281.031706
# 119  285.210815
#
# [120 rows x 18 columns]
# Done with 20240923.

# %%
print(df_tmp_forecasts)
# Out:
#        cfs_run forecast_year forecast_month   eri_basin    eri_lake  \
# 0   2024091800          2024             09  290.438022  290.718765
# 1   2024091800          2024             10  285.436517  285.765962
# 2   2024091800          2024             11  280.460295  280.774295
# 3   2024091800          2024             12  270.470198  271.444908
# 4   2024091800          2025             01  265.423315  266.663449
# 5   2024091800          2025             02  269.623548  269.987015
# 6   2024091800          2025             03  269.735398   269.81036
# 7   2024091800          2025             04   277.08622  276.750215
# 8   2024091800          2025             05  282.630741  281.946436
# 9   2024091800          2025             06  287.616239  286.923307
# 10  2024091806          2024             09  289.446861  289.661428
# 11  2024091806          2024             10  284.027147  284.358049
# 12  2024091806          2024             11  276.323559  276.923877
# 13  2024091806          2024             12  272.528736  273.112519
# 14  2024091806          2025             01  272.729632  272.859713
# 15  2024091806          2025             02  263.162382  264.644127
# 16  2024091806          2025             03   270.72489  271.035996
# 17  2024091806          2025             04   279.33168  278.749794
# 18  2024091806          2025             05  283.600275  282.711337
# 19  2024091806          2025             06  289.521236  288.449185
# 20  2024091812          2024             09  290.651666  290.787031
# 21  2024091812          2024             10  282.740561  283.121597
# 22  2024091812          2024             11  276.786937  277.352172
# 23  2024091812          2024             12  276.572655  276.867625
# 24  2024091812          2025             01  269.608389  270.299254
# 25  2024091812          2025             02  269.389538  270.220688
# 26  2024091812          2025             03  274.974247  274.848695
# 27  2024091812          2025             04  278.646672  278.091192
# 28  2024091812          2025             05  283.470568  282.756339
# 29  2024091812          2025             06  291.315172  290.073195
# 30  2024091818          2024             09  291.554725  291.593164
# 31  2024091818          2024             10  284.644487  284.840924
# 32  2024091818          2024             11  277.980892  278.353182
# 33  2024091818          2024             12  272.138125   272.79754
# 34  2024091818          2025             01  269.177176  269.654026
# 35  2024091818          2025             02  268.346562  268.985881
# 36  2024091818          2025             03  273.705855   273.68713
# 37  2024091818          2025             04  279.777187  279.035154
# 38  2024091818          2025             05  284.257303  283.453642
# 39  2024091818          2025             06  289.993009  288.761372
#
#       eri_land   hur_basin    hur_lake    hur_land   ont_basin    ont_lake  \
# 0   290.309809  289.113874  289.907766  288.763333  289.479747  289.868897
# 1   285.267796  284.379244  285.210733  283.985568  284.699075  285.094322
# 2   280.328485  278.316102  279.490707  277.853653  279.286362  279.699465
# 3   270.130681  268.791377  270.290871  268.038141  270.555915  270.876048
# 4   264.926454   263.88693  266.480728   262.60964   264.56012  265.335502
# 5   269.546511  264.725987  267.474134  263.653773  265.217773  266.167529
# 6   269.765701  266.663132   268.65927  265.728501  265.826975  266.505668
# 7   277.300155  271.400264  273.229236  270.926053  273.191264  273.914209
# 8   282.960343  279.000135  279.677002  279.016111  281.221711  281.490783
# 9   287.955319  284.830555  284.643897  285.227393  286.741628  286.744558
# 10  289.327345  288.939234  289.613679   288.61372   288.85577  289.200906
# 11   283.84236  282.392958  283.517601  281.921833  283.068772  283.442336
# 12  276.039013  274.641922  276.210739   273.95272  275.784923  276.338308
# 13  272.274696  270.550949  272.277699  269.768245  270.898276  271.578894
# 14  272.675935   267.83506  270.073699  267.071883   269.61141  270.272928
# 15  262.588058  261.115048  263.792575   259.93808  264.115358  264.664412
# 16  270.636926  266.303419  268.347152  265.563056  268.643347  269.178988
# 17  279.680317  274.318243  275.684847  274.065177  276.917804  277.325822
# 18  284.061454  280.361077  280.612358  280.502816  281.552549  281.742896
# 19  290.040337  286.545796   286.13964  287.077897  288.250554  288.098916
# 20  290.579106  288.965029  289.831332  288.639379  289.273147  289.733303
# 21  282.577138  280.343734  281.781891  279.785349  281.618775  282.058282
# 22  276.555372   274.42121  275.870569  273.811148  275.654889   276.13306
# 23  276.442753  274.618964  275.831382  274.096545  275.128416  275.666966
# 24   269.34708  268.338982  269.822087  267.583905  268.846985  269.338432
# 25  269.092134  265.284105  267.619674  264.324303  267.645522  268.224592
# 26  275.146528  269.301257   271.22114  268.626917  270.143761  270.795555
# 27  278.976188  274.418359  275.590486  274.157603  275.939869  276.287574
# 28  283.828903  281.356127  281.242507  281.632583  282.653789  282.661457
# 29  291.892431   288.73686  287.989227  289.499799  290.765952  290.490769
# 30   291.49544  290.452905  291.052676  290.209164  290.122113  290.580241
# 31  284.526102  282.508079  283.607577  282.076275  283.329237   283.75407
# 32  277.769364  276.887871  278.086061  276.304107  276.865292  277.326391
# 33  271.871924  269.626084  271.491611  268.858587  271.728226  272.159636
# 34  268.938686  267.923254  269.749064  267.032264  268.221829  268.873251
# 35  268.074457  265.575846  267.659001  264.636256  265.387133  266.112316
# 36  273.802296  268.747703  270.888983   268.03227  270.011823  270.794801
# 37  280.168779  275.874359  276.900317  275.644092  275.929674  276.636954
# 38  284.659917   281.79643  281.706807  282.090811  283.173697  283.176432
# 39  290.580337  287.553737  286.726235  288.251566  288.656405  288.514993
#
#       ont_land   mic_basin    mic_lake    mic_land   sup_basin    sup_lake  \
# 0   289.158039  289.392105  289.870566   289.15529   287.87149  287.950658
# 1   284.307262  284.470322  284.832567  284.248385  282.965611  283.611611
# 2   278.987495  278.848394  279.357636  278.615828  275.649311  276.960539
# 3   270.381804   266.62866  266.959405  266.250247  262.904641  265.422968
# 4   264.175499   263.27656  263.767776  262.685149  259.495544  262.700955
# 5   265.076475  267.676428  268.380986  267.288818   261.25297  264.145704
# 6   265.541656  268.262194  268.802113  267.900986  263.986751  266.340562
# 7   273.111636  274.838614  275.760732   274.67402  268.040554  269.706871
# 8   281.199545  281.159399  281.666259  281.284173  275.902013  276.452945
# 9   286.850605  286.562616  286.804977  286.827051  283.954152  282.437988
# 10  288.509757  289.227627   289.64294  288.989474   287.41965   287.61175
# 11  282.748559  282.823238  283.319502  282.580966  279.760704  280.841276
# 12  275.410166  274.714179  275.237727  274.364606  271.793589  273.454289
# 13  270.521822  270.952753  271.488914  270.584138  267.724197  269.859746
# 14  269.370485  269.185174  270.111217   268.87265  260.779239  263.907428
# 15  263.867565  260.313082  260.901952   259.63926  255.174484  258.585694
# 16  268.433967  268.356233  269.124969  268.046691  263.093886  265.353703
# 17   276.88437   277.33756  278.148574  277.289758  270.281299  271.643923
# 18  281.537804  282.812924  283.190837  283.003128  278.944022  278.727796
# 19     288.489  288.430153   288.74224  288.716993  284.424472  282.876043
# 20  288.949244  289.814194  290.269944  289.632437  287.234784  287.500414
# 21  281.300649  281.172429  281.806619  280.904274  277.627648  278.918159
# 22  275.334876  274.914856  275.574366  274.570983  272.041296  273.546142
# 23  274.822351  274.985542  275.401849  274.743761  272.182381  273.693664
# 24  268.423001  266.053861  266.426115  265.724493   263.93856  266.151728
# 25  267.556613   264.38778  264.867401  264.034292  260.293278  262.927844
# 26  270.193131  273.145586  273.793165   273.00423  268.816498  270.403787
# 27  275.932284  277.054518  277.618668  277.073985  272.332713   273.18232
# 28   282.72573  282.882618  283.252391  283.026825  280.099967  279.402146
# 29  291.093792  290.365941  290.462842  290.748883  286.509524  284.431771
# 30  289.757786  290.570529  291.026693  290.394146  288.212149  288.329907
# 31  282.996962  283.485349  283.975846  283.261042  280.549821  281.583181
# 32  276.461628   277.08318  277.504132  276.776248  275.682744   276.91402
# 33  271.509523  268.223515  268.913492  267.807796  263.314318  266.059261
# 34  267.789506  267.669614  268.248582  267.220889  264.626272  267.048342
# 35  265.085836  267.302401  267.875817  266.828872  263.366817  266.072299
# 36  269.775524  271.580245  272.464013  271.303208  264.869656  267.232117
# 37  275.747587  279.325718   280.07709  279.270833  274.891241  275.496331
# 38   283.30156  283.198922  283.530034  283.381406  280.513888  279.798564
# 39  288.856141  289.524392  289.832827  289.840425  285.697651  283.816738
#
#       sup_land
# 0   287.796153
# 1   282.458642
# 2   274.676879
# 3   261.029587
# 4   257.090507
# 5   259.149605
# 6   262.231348
# 7    266.84567
# 8   275.632861
# 9   285.094824
# 10  287.276324
# 11  278.977964
# 12  270.570279
# 13  266.134472
# 14  258.465887
# 15  252.551904
# 16  261.451437
# 17  269.398434
# 18  279.156004
# 19  285.600155
# 20  287.046475
# 21    276.7155
# 22  270.917131
# 23  271.067014
# 24  262.227111
# 25  258.286313
# 26  267.688117
# 27  271.753004
# 28  280.651161
# 29  288.047317
# 30   288.14592
# 31  279.808899
# 32  274.739763
# 33  261.210844
# 34  262.802834
# 35  261.323676
# 36  263.182991
# 37  274.474221
# 38  281.056323
# 39  287.119056

# %% [markdown]
# Close any open files before finishing script.

# %%
df_tmp_forecasts.to_csv(tmp_csv, sep=',', index=False)
df_evap_forecasts.to_csv(evap_csv, sep=',', index=False)
df_pcp_forecasts.to_csv(pcp_csv, sep=',', index=False)

# %%
print(df_tmp_forecasts)
# Out:
#        cfs_run forecast_year forecast_month   eri_basin    eri_lake  \
# 0   2024091800          2024             09  290.438022  290.718765
# 1   2024091800          2024             10  285.436517  285.765962
# 2   2024091800          2024             11  280.460295  280.774295
# 3   2024091800          2024             12  270.470198  271.444908
# 4   2024091800          2025             01  265.423315  266.663449
# 5   2024091800          2025             02  269.623548  269.987015
# 6   2024091800          2025             03  269.735398   269.81036
# 7   2024091800          2025             04   277.08622  276.750215
# 8   2024091800          2025             05  282.630741  281.946436
# 9   2024091800          2025             06  287.616239  286.923307
# 10  2024091806          2024             09  289.446861  289.661428
# 11  2024091806          2024             10  284.027147  284.358049
# 12  2024091806          2024             11  276.323559  276.923877
# 13  2024091806          2024             12  272.528736  273.112519
# 14  2024091806          2025             01  272.729632  272.859713
# 15  2024091806          2025             02  263.162382  264.644127
# 16  2024091806          2025             03   270.72489  271.035996
# 17  2024091806          2025             04   279.33168  278.749794
# 18  2024091806          2025             05  283.600275  282.711337
# 19  2024091806          2025             06  289.521236  288.449185
# 20  2024091812          2024             09  290.651666  290.787031
# 21  2024091812          2024             10  282.740561  283.121597
# 22  2024091812          2024             11  276.786937  277.352172
# 23  2024091812          2024             12  276.572655  276.867625
# 24  2024091812          2025             01  269.608389  270.299254
# 25  2024091812          2025             02  269.389538  270.220688
# 26  2024091812          2025             03  274.974247  274.848695
# 27  2024091812          2025             04  278.646672  278.091192
# 28  2024091812          2025             05  283.470568  282.756339
# 29  2024091812          2025             06  291.315172  290.073195
# 30  2024091818          2024             09  291.554725  291.593164
# 31  2024091818          2024             10  284.644487  284.840924
# 32  2024091818          2024             11  277.980892  278.353182
# 33  2024091818          2024             12  272.138125   272.79754
# 34  2024091818          2025             01  269.177176  269.654026
# 35  2024091818          2025             02  268.346562  268.985881
# 36  2024091818          2025             03  273.705855   273.68713
# 37  2024091818          2025             04  279.777187  279.035154
# 38  2024091818          2025             05  284.257303  283.453642
# 39  2024091818          2025             06  289.993009  288.761372
#
#       eri_land   hur_basin    hur_lake    hur_land   ont_basin    ont_lake  \
# 0   290.309809  289.113874  289.907766  288.763333  289.479747  289.868897
# 1   285.267796  284.379244  285.210733  283.985568  284.699075  285.094322
# 2   280.328485  278.316102  279.490707  277.853653  279.286362  279.699465
# 3   270.130681  268.791377  270.290871  268.038141  270.555915  270.876048
# 4   264.926454   263.88693  266.480728   262.60964   264.56012  265.335502
# 5   269.546511  264.725987  267.474134  263.653773  265.217773  266.167529
# 6   269.765701  266.663132   268.65927  265.728501  265.826975  266.505668
# 7   277.300155  271.400264  273.229236  270.926053  273.191264  273.914209
# 8   282.960343  279.000135  279.677002  279.016111  281.221711  281.490783
# 9   287.955319  284.830555  284.643897  285.227393  286.741628  286.744558
# 10  289.327345  288.939234  289.613679   288.61372   288.85577  289.200906
# 11   283.84236  282.392958  283.517601  281.921833  283.068772  283.442336
# 12  276.039013  274.641922  276.210739   273.95272  275.784923  276.338308
# 13  272.274696  270.550949  272.277699  269.768245  270.898276  271.578894
# 14  272.675935   267.83506  270.073699  267.071883   269.61141  270.272928
# 15  262.588058  261.115048  263.792575   259.93808  264.115358  264.664412
# 16  270.636926  266.303419  268.347152  265.563056  268.643347  269.178988
# 17  279.680317  274.318243  275.684847  274.065177  276.917804  277.325822
# 18  284.061454  280.361077  280.612358  280.502816  281.552549  281.742896
# 19  290.040337  286.545796   286.13964  287.077897  288.250554  288.098916
# 20  290.579106  288.965029  289.831332  288.639379  289.273147  289.733303
# 21  282.577138  280.343734  281.781891  279.785349  281.618775  282.058282
# 22  276.555372   274.42121  275.870569  273.811148  275.654889   276.13306
# 23  276.442753  274.618964  275.831382  274.096545  275.128416  275.666966
# 24   269.34708  268.338982  269.822087  267.583905  268.846985  269.338432
# 25  269.092134  265.284105  267.619674  264.324303  267.645522  268.224592
# 26  275.146528  269.301257   271.22114  268.626917  270.143761  270.795555
# 27  278.976188  274.418359  275.590486  274.157603  275.939869  276.287574
# 28  283.828903  281.356127  281.242507  281.632583  282.653789  282.661457
# 29  291.892431   288.73686  287.989227  289.499799  290.765952  290.490769
# 30   291.49544  290.452905  291.052676  290.209164  290.122113  290.580241
# 31  284.526102  282.508079  283.607577  282.076275  283.329237   283.75407
# 32  277.769364  276.887871  278.086061  276.304107  276.865292  277.326391
# 33  271.871924  269.626084  271.491611  268.858587  271.728226  272.159636
# 34  268.938686  267.923254  269.749064  267.032264  268.221829  268.873251
# 35  268.074457  265.575846  267.659001  264.636256  265.387133  266.112316
# 36  273.802296  268.747703  270.888983   268.03227  270.011823  270.794801
# 37  280.168779  275.874359  276.900317  275.644092  275.929674  276.636954
# 38  284.659917   281.79643  281.706807  282.090811  283.173697  283.176432
# 39  290.580337  287.553737  286.726235  288.251566  288.656405  288.514993
#
#       ont_land   mic_basin    mic_lake    mic_land   sup_basin    sup_lake  \
# 0   289.158039  289.392105  289.870566   289.15529   287.87149  287.950658
# 1   284.307262  284.470322  284.832567  284.248385  282.965611  283.611611
# 2   278.987495  278.848394  279.357636  278.615828  275.649311  276.960539
# 3   270.381804   266.62866  266.959405  266.250247  262.904641  265.422968
# 4   264.175499   263.27656  263.767776  262.685149  259.495544  262.700955
# 5   265.076475  267.676428  268.380986  267.288818   261.25297  264.145704
# 6   265.541656  268.262194  268.802113  267.900986  263.986751  266.340562
# 7   273.111636  274.838614  275.760732   274.67402  268.040554  269.706871
# 8   281.199545  281.159399  281.666259  281.284173  275.902013  276.452945
# 9   286.850605  286.562616  286.804977  286.827051  283.954152  282.437988
# 10  288.509757  289.227627   289.64294  288.989474   287.41965   287.61175
# 11  282.748559  282.823238  283.319502  282.580966  279.760704  280.841276
# 12  275.410166  274.714179  275.237727  274.364606  271.793589  273.454289
# 13  270.521822  270.952753  271.488914  270.584138  267.724197  269.859746
# 14  269.370485  269.185174  270.111217   268.87265  260.779239  263.907428
# 15  263.867565  260.313082  260.901952   259.63926  255.174484  258.585694
# 16  268.433967  268.356233  269.124969  268.046691  263.093886  265.353703
# 17   276.88437   277.33756  278.148574  277.289758  270.281299  271.643923
# 18  281.537804  282.812924  283.190837  283.003128  278.944022  278.727796
# 19     288.489  288.430153   288.74224  288.716993  284.424472  282.876043
# 20  288.949244  289.814194  290.269944  289.632437  287.234784  287.500414
# 21  281.300649  281.172429  281.806619  280.904274  277.627648  278.918159
# 22  275.334876  274.914856  275.574366  274.570983  272.041296  273.546142
# 23  274.822351  274.985542  275.401849  274.743761  272.182381  273.693664
# 24  268.423001  266.053861  266.426115  265.724493   263.93856  266.151728
# 25  267.556613   264.38778  264.867401  264.034292  260.293278  262.927844
# 26  270.193131  273.145586  273.793165   273.00423  268.816498  270.403787
# 27  275.932284  277.054518  277.618668  277.073985  272.332713   273.18232
# 28   282.72573  282.882618  283.252391  283.026825  280.099967  279.402146
# 29  291.093792  290.365941  290.462842  290.748883  286.509524  284.431771
# 30  289.757786  290.570529  291.026693  290.394146  288.212149  288.329907
# 31  282.996962  283.485349  283.975846  283.261042  280.549821  281.583181
# 32  276.461628   277.08318  277.504132  276.776248  275.682744   276.91402
# 33  271.509523  268.223515  268.913492  267.807796  263.314318  266.059261
# 34  267.789506  267.669614  268.248582  267.220889  264.626272  267.048342
# 35  265.085836  267.302401  267.875817  266.828872  263.366817  266.072299
# 36  269.775524  271.580245  272.464013  271.303208  264.869656  267.232117
# 37  275.747587  279.325718   280.07709  279.270833  274.891241  275.496331
# 38   283.30156  283.198922  283.530034  283.381406  280.513888  279.798564
# 39  288.856141  289.524392  289.832827  289.840425  285.697651  283.816738
#
#       sup_land
# 0   287.796153
# 1   282.458642
# 2   274.676879
# 3   261.029587
# 4   257.090507
# 5   259.149605
# 6   262.231348
# 7    266.84567
# 8   275.632861
# 9   285.094824
# 10  287.276324
# 11  278.977964
# 12  270.570279
# 13  266.134472
# 14  258.465887
# 15  252.551904
# 16  261.451437
# 17  269.398434
# 18  279.156004
# 19  285.600155
# 20  287.046475
# 21    276.7155
# 22  270.917131
# 23  271.067014
# 24  262.227111
# 25  258.286313
# 26  267.688117
# 27  271.753004
# 28  280.651161
# 29  288.047317
# 30   288.14592
# 31  279.808899
# 32  274.739763
# 33  261.210844
# 34  262.802834
# 35  261.323676
# 36  263.182991
# 37  274.474221
# 38  281.056323
# 39  287.119056

# %%
mask_ds.close()
